# %%
from pathlib import Path
import json
from functools import reduce
import math
import datetime as dt
import pytz 
from itertools import product
from collections import OrderedDict
import time
import re

import requests
import numpy as np
import pandas as pd
import geopandas as gpd
import shapely.ops as so

ROOT = Path('../')
DATA_DIR = ROOT/'data'

# %%
# Car costs
# Use 30%/year diminishing value for cars taken from IRD depreciation calculator (https://interact1.ird.govt.nz/forms/depnrates/6f2b363212311e77353c7a1f373c6e2229472e70.continue;jsessionid=8C181312A1BA5BD98EE39396468C2E94)

def value(purchase_price, num_years, depreciation_rate=0.3):
    x = purchase_price
    n = num_years
    k = math.floor(n)
    kk = n - k
    r = depreciation_rate
    if n <= 0:
        d = 0
    else:
        d = sum([x*r**i for i in range(1, k + 1)]) + kk*x*r**(k + 1)
    return x - d

value(50679, 2)

# %% [markdown]
# # Compute Auckland and Wellington fares through their web APIs

# %%
def get_journey_auckland(orig, dest, departure_time=None):
    """
    INPUT
    ------
    orig : list
        WGS84 longitude-latitude pair
    dest : list
        WGS84 longitude-latitude pair
    departure_time : string
        ISO 8601 datetime; e.g. '2017-06-01T07:30:00'
        
    OUTPUT
    ------
    dictionary
        Decoded JSON response of journey
    """
    url = 'https://api.at.govt.nz/v2/public-restricted/journeyplanner/silverRailIVU/plan'
    fromLoc ='{!s},{!s}'.format(orig[1], orig[0])
    toLoc ='{!s},{!s}'.format(dest[1], dest[0])
    if departure_time is None:
        departure_time = dt.datetime.now().strftime('%Y-%m-%dT%H:%M:%S')
    date = departure_time + '+12:00'  # Add UTC offset
    params = {
        'from': 'from',
        'to': 'to',
        'fromLoc': fromLoc,
        'toLoc': toLoc,
        'timeMode': 'A',
        'date': date, 
        'modes': 'BUS,TRAIN,FERRY',
        'operators': '',
        'optimize': 'QUICK',
        'maxWalk': 2000,
        'maxChanges': '-1',
        'routes': '',
        'subscription-key': '323741614c1c4b9083299adefe100aa6',
    }
    r = requests.get(url, params=params)
    
    # Raise an error if bad request
    r.raise_for_status()

    return r.json()         

def get_fare_auckland(journey):
    """
    Given a journey of the form output by :func:`get_journey_auckland`, 
    return the journey's adult fare (float)'
    """
    try:
        fare = journey['response']['itineraries'][0]['fareAdult']/100
    except:
        fare = None
    return fare

def get_journey_wellington(orig, dest, departure_time=None):
    """
    INPUT
    ------
    orig : list
        WGS84 longitude-latitude pair
    dest : list
        WGS84 longitude-latitude pair
    departure_time : string
        ISO 8601 datetime; e.g. '2017-06-01T07:30:00'
        
    OUTPUT
    ------
    text
        HTML response of journey query
    """
    url = 'https://www.metlink.org.nz/journeyplanner/JourneyPlannerForm'
    from_coords ='{!s},{!s}'.format(orig[1], orig[0])
    to_coords ='{!s},{!s}'.format(dest[1], dest[0])
    
    if departure_time is None:
        departure_time = dt.datetime.now().strftime('%Y-%m-%dT%H:%M:%S')
    date, time = departure_time.split('T')
        
    params = {
        'From': 'from',
        'To': 'to', 
        'Via': '',
        'When': 'LeaveAfter',
        'Date': date,
        'Time': time,
        'MaxChanges': 5,
        'WalkingSpeed': 4,
        'MaxWalking': 2000,
        'Modes[Train]': 'Train',
        'Modes[Bus]': 'Bus',
        'Modes[Ferry]': 'Ferry',
        'Modes[Cable+Car]': 'Cable Car',
        'ShowAdvanced': '',
        'FromCoords': from_coords,
        'ToCoords': to_coords,
        'ViaCoords': '',
        'action_doForm': 'Go',
    }
    r = requests.get(url, params=params)
    # Raise an error if bad request
    r.raise_for_status()
    return r.text         

# Estimate Wellington card fare discount
path = DATA_DIR/'wellington'/'transit_fares.csv'
f = pd.read_csv(path)
f['card/cash'] = f['card_fare']/f['cash_fare']
r = f['card/cash'].mean()
print('estimated Wellington card discount rate=', r)

def get_fare_wellington(journey, card_discount=r):
    """
    Given a journey of the form output by :func:`get_journey_wellington`, 
    extract the journey's adult cash fare (float), multiply it by the given
    discount rate to estimate the adult card fare, and return the result.
    """
    pattern = 'Total adult fare </span><strong>&#36;(\d+\.\d\d)</strong>'
    m = re.search(pattern, journey)
    if m:
        fare = float(m.group(1))
    else:
        fare = None
    return round(r*fare, 2)

def collect_fares(rental_points, departure_time, region):
    """
    """
    # Get all pairs of points excluding equal points
    f = rental_points[['rental_area', 'geometry']].copy()
    rows = [[o[0], o[1].coords[0], d[0], d[1].coords[0]] for o, d in product(f.values, f.values) if o[0] != d[0]]
    f = pd.DataFrame(rows, columns=['orig_name', 'orig', 'dest_name', 'dest'])

    if region == 'auckland':
        get_journey = get_journey_auckland
        get_fare = get_fare_auckland
        time_per_call = 3.6
    elif region == 'wellington':
        get_journey = get_journey_wellington
        get_fare = get_fare_wellington
        time_per_call = 2.4
    
    print('This will take about {:02f} minutes'.format(f.shape[0]*time_per_call/60))

    # Get journeys for each pair
    rows = []
    for __, row in f.iterrows():
        try:
            j = get_journey(row['orig'], row['dest'], departure_time=departure_time)
            fare = get_fare(j)
        except:
            fare = None
        rows.append([row['orig_name'], row['dest_name'], fare])

    g = pd.DataFrame(rows, columns=['orig_name', 'dest_name', 'card_fare'])
    return g
# Out:
# estimated Wellington card discount rate= 0.782401654073

# %%
# Test some
orig = [174.7433853149414, -36.85517522550505]
dest = [174.79625701904297, -36.82550066651677]
# %time j = get_journey_auckland(orig, dest)
j
get_fare_auckland(j)

orig = (174.7708511352539,-41.28394744513899)
dest = (174.78861808776855,-41.297458248607995)
# %time r = get_journey_wellington(orig, dest, departure_time='2017-06-01T07:30:00')
r
get_fare_wellington(r)

# %%
regions = ['auckland', 'wellington']
for region in regions:
    path = DATA_DIR/region/'rental_points.geojson'
    rp = gpd.read_file(str(path))
    departure_time = '2017-06-01T07:30:00'
    g = collect_fares(rp, departure_time, region)

    path = DATA_DIR/region/'transit_costs.csv'
    g.to_csv(str(path), index=False)
    print('* ', region)
    print(g.head())
# Out:
# This will take about 72.240000 minutes
# *  wellington
#   orig_name                  dest_name  fare
# 0  Brooklyn  Carterton/South Wairarapa   NaN
# 1  Brooklyn               Eastern Bays  14.5
# 2  Brooklyn               Epuni/Avalon  12.5
# 3  Brooklyn                   Hataitai  10.5
# 4  Brooklyn    Heretaunga/Silverstream  16.5

# %% [markdown]
# # Canterbury has no fare calculator API. So timate Canterbury fares from fare zones and fare table.

# %%
# Fares
fares = pd.DataFrame([[1, 2.55], [2, 3.75]], columns=['#zones_traveled', 'card_fare'])
fares

# Zones
path = DATA_DIR/'canterbury'/'fare_zones.geojson'
zones = gpd.read_file(str(path))
zones

# Attach zones to rental points
path = DATA_DIR/'canterbury'/'rental_points.geojson'
rp = gpd.read_file(str(path))
g = gpd.sjoin(rp, zones, op='within')
g = g[['rental_area', 'zone']].copy()
g.head()

# Compute origin and destination zones
path = DATA_DIR/'canterbury'/'commutes_transit.csv'
f = pd.read_csv(path)
f = f.merge(g.rename(columns={'rental_area': 'orig_name', 'zone': 'orig_zone'}))
f = f.merge(g.rename(columns={'rental_area': 'dest_name', 'zone': 'dest_zone'}))

# Compute #zones traveled, then card fare, nullifying fares for which there is no transit distance
f['#zones_traveled'] = abs(f['orig_zone'] - f['dest_zone']) + 1
f = f.merge(fares)
cond = f['distance'].isnull()
f.loc[cond, 'card_fare'] = np.nan
f
# Out:
#                                                    orig  \
# 0                                   -43.31447,172.61712
# 1                                   -43.62091,172.41804
# 2                                   -43.47051,172.69491
# 3                                   -43.47162,172.60532
# 4                                   -43.48362,172.64646
# 5                                   -43.49642,172.57196
# 6                                   -43.49947,172.59606
# 7                                    -43.50357,172.6322
# 8                                   -43.50392,172.65522
# 9                                    -43.50759,172.6816
# 10                                  -43.50935,172.72447
# 11                                    -43.5145,172.5993
# 12                                  -43.51461,172.64218
# 13                                  -43.51642,172.62366
# 14                                  -43.51787,172.56798
# 15                                  -43.52048,172.53567
# 16                                  -43.52132,172.69875
# 17                                  -43.52141,172.66402
# 18                                   -43.5257,172.64341
# 19                                  -43.53178,172.56318
# 20                                  -43.53233,172.66316
# 21                                  -43.53241,172.59615
# 22                                  -43.53337,172.63536
# 23                                  -43.54062,172.52537
# 24                                  -43.54384,172.61755
# 25                                  -43.54914,172.67387
# 26                                  -43.54956,172.64137
# 27                                  -43.55406,172.61817
# 28                                  -43.55995,172.59691
# 29                                  -43.56316,172.65616
# ...                                                 ...
# 1026  185 Cavendish Rd, Casebrook, Christchurch 8051...
# 1027  637-679 Hills Rd, Marshland, Christchurch 8051...
# 1028  26 Nepal Pl, Burnside, Christchurch 8053, New ...
# 1029  51-53 Hudson St, Bryndwr, Christchurch 8053, N...
# 1030  46 Roosevelt Ave, St Albans, Christchurch 8014...
# 1031  5 Jebson St, Mairehau, Christchurch 8013, New ...
# 1032  267 Locksley Ave, Dallington, Christchurch 806...
# 1033  98 Beresford St, New Brighton, Christchurch 80...
# 1034  9-11 Garreg Rd, Fendalton, Christchurch 8052, ...
# 1035  535a Madras St, St Albans, Christchurch 8014, ...
# 1036  130-154 Merivale Ln, Merivale, Christchurch 80...
# 1037  3 McLellan Pl, Ilam, Christchurch 8041, New Ze...
# 1038  406-408 Yaldhurst Rd, Russley, Christchurch 80...
# 1039  246 Pages Rd, Wainoni, Christchurch 8062, New ...
# 1040  55 Cowlishaw St, Avonside, Christchurch 8061, ...
# 1041  218-220 Peterborough St, Christchurch Central,...
# 1042  22-24 English St, Sockburn, Christchurch 8042,...
# 1043  532A Hereford St, Linwood, Christchurch 8011, ...
# 1044  33a Maxwell St, Riccarton, Christchurch 8041, ...
# 1045  120 Cashel St, Christchurch Central, Christchu...
# 1046  5-11 Smarts Rd, Hornby, Christchurch 8042, New...
# 1047  7 Church Square, Addington, Christchurch 8024,...
# 1048  62 Richardson Terrace, Woolston, Christchurch ...
# 1049  31A Sugden St, Spreydon, Christchurch 8024, Ne...
# 1050  40 Mathers Rd, Hoon Hay, Christchurch 8025, Ne...
# 1051  224 Centaurus Rd, St Martins, Christchurch 802...
# 1052  114 Moncks Spur Rd, Redcliffs, Christchurch 80...
# 1053  5 Jarrow Pl, Halswell, Christchurch 8025, New ...
# 1054  55 Valley Rd, Cashmere, Christchurch 8022, New...
# 1055                                -43.62091,172.41804
#
#                                 orig_name  \
# 0                        Rangiora/Kaiapoi
# 1                  Banks Peninsula/Selwyn
# 2                          Styx/Parklands
# 3          Sawyers Arms/Northcote/Belfast
# 4                       Marshland/Redwood
# 5                       Burnside/Harewood
# 6                      Bishopdale/Papanui
# 7               St Albans North/ Mairehau
# 8                        Richmond/Shirley
# 9             Burwood/Dallington/Avondale
# 10    North Beach/New Brighton/Southshore
# 11              Fendalton/Strowan/Bryndwr
# 12                St Albans East/Edgeware
# 13                Merivale/St Albans West
# 14                          Ilam/Westburn
# 15                     Avonhead/Yaldhurst
# 16                  Aranui/Bromley/Bexley
# 17                      Richmond/Avonside
# 18            Avon Loop/Christchurch East
# 19               Sockburn/Upper Riccarton
# 20                   Linwood/Phillipstown
# 21                              Riccarton
# 22            Christchurch Central/Hagley
# 23                Horby/Islington/Hei Hei
# 24                              Addington
# 25                         Woolston/Opawa
# 26                       Sydenham/Waltham
# 27                    Spreydon/Somerfield
# 28                    Hillmorton/Hoon Hay
# 29         St Martins/Beckenham/Huntsbury
# ...                                   ...
# 1026       Sawyers Arms/Northcote/Belfast
# 1027                    Marshland/Redwood
# 1028                    Burnside/Harewood
# 1029                   Bishopdale/Papanui
# 1030            St Albans North/ Mairehau
# 1031                     Richmond/Shirley
# 1032          Burwood/Dallington/Avondale
# 1033  North Beach/New Brighton/Southshore
# 1034            Fendalton/Strowan/Bryndwr
# 1035              St Albans East/Edgeware
# 1036              Merivale/St Albans West
# 1037                        Ilam/Westburn
# 1038                   Avonhead/Yaldhurst
# 1039                Aranui/Bromley/Bexley
# 1040                    Richmond/Avonside
# 1041          Avon Loop/Christchurch East
# 1042             Sockburn/Upper Riccarton
# 1043                 Linwood/Phillipstown
# 1044                            Riccarton
# 1045          Christchurch Central/Hagley
# 1046              Horby/Islington/Hei Hei
# 1047                            Addington
# 1048                       Woolston/Opawa
# 1049                  Spreydon/Somerfield
# 1050                  Hillmorton/Hoon Hay
# 1051       St Martins/Beckenham/Huntsbury
# 1052                     Redcliffs/Sumner
# 1053                      Halswell/Wigram
# 1054      Westmorland/Cashmere/Barrington
# 1055               Banks Peninsula/Selwyn
#
#                                                    dest  \
# 0                                   -43.52141,172.66402
# 1                                   -43.52141,172.66402
# 2                                   -43.62091,172.41804
# 3                                   -43.62091,172.41804
# 4                                   -43.62091,172.41804
# 5                                   -43.62091,172.41804
# 6                                   -43.62091,172.41804
# 7                                   -43.62091,172.41804
# 8                                   -43.62091,172.41804
# 9                                   -43.62091,172.41804
# 10                                  -43.62091,172.41804
# 11                                  -43.62091,172.41804
# 12                                  -43.62091,172.41804
# 13                                  -43.62091,172.41804
# 14                                  -43.62091,172.41804
# 15                                  -43.62091,172.41804
# 16                                  -43.62091,172.41804
# 17                                  -43.62091,172.41804
# 18                                  -43.62091,172.41804
# 19                                  -43.62091,172.41804
# 20                                  -43.62091,172.41804
# 21                                  -43.62091,172.41804
# 22                                  -43.62091,172.41804
# 23                                  -43.62091,172.41804
# 24                                  -43.62091,172.41804
# 25                                  -43.62091,172.41804
# 26                                  -43.62091,172.41804
# 27                                  -43.62091,172.41804
# 28                                  -43.62091,172.41804
# 29                                  -43.62091,172.41804
# ...                                                 ...
# 1026  9B Burlington St, Sydenham, Christchurch 8023,...
# 1027  9B Burlington St, Sydenham, Christchurch 8023,...
# 1028  9B Burlington St, Sydenham, Christchurch 8023,...
# 1029  9B Burlington St, Sydenham, Christchurch 8023,...
# 1030  9B Burlington St, Sydenham, Christchurch 8023,...
# 1031  9B Burlington St, Sydenham, Christchurch 8023,...
# 1032  9B Burlington St, Sydenham, Christchurch 8023,...
# 1033  9B Burlington St, Sydenham, Christchurch 8023,...
# 1034  9B Burlington St, Sydenham, Christchurch 8023,...
# 1035  9B Burlington St, Sydenham, Christchurch 8023,...
# 1036  9B Burlington St, Sydenham, Christchurch 8023,...
# 1037  9B Burlington St, Sydenham, Christchurch 8023,...
# 1038  9B Burlington St, Sydenham, Christchurch 8023,...
# 1039  9B Burlington St, Sydenham, Christchurch 8023,...
# 1040  9B Burlington St, Sydenham, Christchurch 8023,...
# 1041  9B Burlington St, Sydenham, Christchurch 8023,...
# 1042  9B Burlington St, Sydenham, Christchurch 8023,...
# 1043  9B Burlington St, Sydenham, Christchurch 8023,...
# 1044  9B Burlington St, Sydenham, Christchurch 8023,...
# 1045  9B Burlington St, Sydenham, Christchurch 8023,...
# 1046  9B Burlington St, Sydenham, Christchurch 8023,...
# 1047  9B Burlington St, Sydenham, Christchurch 8023,...
# 1048  9B Burlington St, Sydenham, Christchurch 8023,...
# 1049  9B Burlington St, Sydenham, Christchurch 8023,...
# 1050  9B Burlington St, Sydenham, Christchurch 8023,...
# 1051  9B Burlington St, Sydenham, Christchurch 8023,...
# 1052  9B Burlington St, Sydenham, Christchurch 8023,...
# 1053  9B Burlington St, Sydenham, Christchurch 8023,...
# 1054  9B Burlington St, Sydenham, Christchurch 8023,...
# 1055  149-159 Boys Rd, Waimakariri, Rangiora 7400, N...
#
#                    dest_name  duration  distance  orig_zone  dest_zone  \
# 0          Richmond/Avonside       NaN       NaN          2          1
# 1          Richmond/Avonside       NaN       NaN          2          1
# 2     Banks Peninsula/Selwyn       NaN       NaN          1          2
# 3     Banks Peninsula/Selwyn       NaN       NaN          1          2
# 4     Banks Peninsula/Selwyn       NaN       NaN          1          2
# 5     Banks Peninsula/Selwyn       NaN       NaN          1          2
# 6     Banks Peninsula/Selwyn       NaN       NaN          1          2
# 7     Banks Peninsula/Selwyn       NaN       NaN          1          2
# 8     Banks Peninsula/Selwyn       NaN       NaN          1          2
# 9     Banks Peninsula/Selwyn       NaN       NaN          1          2
# 10    Banks Peninsula/Selwyn       NaN       NaN          1          2
# 11    Banks Peninsula/Selwyn       NaN       NaN          1          2
# 12    Banks Peninsula/Selwyn       NaN       NaN          1          2
# 13    Banks Peninsula/Selwyn       NaN       NaN          1          2
# 14    Banks Peninsula/Selwyn       NaN       NaN          1          2
# 15    Banks Peninsula/Selwyn       NaN       NaN          1          2
# 16    Banks Peninsula/Selwyn       NaN       NaN          1          2
# 17    Banks Peninsula/Selwyn       NaN       NaN          1          2
# 18    Banks Peninsula/Selwyn       NaN       NaN          1          2
# 19    Banks Peninsula/Selwyn       NaN       NaN          1          2
# 20    Banks Peninsula/Selwyn       NaN       NaN          1          2
# 21    Banks Peninsula/Selwyn       NaN       NaN          1          2
# 22    Banks Peninsula/Selwyn       NaN       NaN          1          2
# 23    Banks Peninsula/Selwyn       NaN       NaN          1          2
# 24    Banks Peninsula/Selwyn       NaN       NaN          1          2
# 25    Banks Peninsula/Selwyn       NaN       NaN          1          2
# 26    Banks Peninsula/Selwyn       NaN       NaN          1          2
# 27    Banks Peninsula/Selwyn       NaN       NaN          1          2
# 28    Banks Peninsula/Selwyn       NaN       NaN          1          2
# 29    Banks Peninsula/Selwyn       NaN       NaN          1          2
# ...                      ...       ...       ...        ...        ...
# 1026        Sydenham/Waltham    3620.0   13066.0          1          1
# 1027        Sydenham/Waltham    3572.0    9896.0          1          1
# 1028        Sydenham/Waltham    2707.0   11598.0          1          1
# 1029        Sydenham/Waltham    2418.0    9732.0          1          1
# 1030        Sydenham/Waltham    1608.0    7026.0          1          1
# 1031        Sydenham/Waltham    2752.0    7869.0          1          1
# 1032        Sydenham/Waltham    2637.0    9690.0          1          1
# 1033        Sydenham/Waltham    2790.0   11855.0          1          1
# 1034        Sydenham/Waltham    2605.0    8430.0          1          1
# 1035        Sydenham/Waltham    1942.0    5826.0          1          1
# 1036        Sydenham/Waltham    1320.0    5951.0          1          1
# 1037        Sydenham/Waltham    2534.0   10108.0          1          1
# 1038        Sydenham/Waltham    3428.0   14657.0          1          1
# 1039        Sydenham/Waltham    2544.0    9163.0          1          1
# 1040        Sydenham/Waltham    3508.0    4612.0          1          1
# 1041        Sydenham/Waltham    1167.0    4101.0          1          1
# 1042        Sydenham/Waltham    2818.0    9265.0          1          1
# 1043        Sydenham/Waltham    2125.0    5207.0          1          1
# 1044        Sydenham/Waltham    1881.0    6783.0          1          1
# 1045        Sydenham/Waltham     861.0    2790.0          1          1
# 1046        Sydenham/Waltham    3337.0   12816.0          1          1
# 1047        Sydenham/Waltham    1480.0    3101.0          1          1
# 1048        Sydenham/Waltham    1372.0    3276.0          1          1
# 1049        Sydenham/Waltham     946.0    2764.0          1          1
# 1050        Sydenham/Waltham    1697.0    5110.0          1          1
# 1051        Sydenham/Waltham     769.0    3205.0          1          1
# 1052        Sydenham/Waltham    3587.0   13263.0          1          1
# 1053        Sydenham/Waltham    3722.0    9654.0          1          1
# 1054        Sydenham/Waltham    1426.0    4215.0          1          1
# 1055        Rangiora/Kaiapoi       NaN       NaN          2          2
#
#       #zones_traveled  card_fare
# 0                   2        NaN
# 1                   2        NaN
# 2                   2        NaN
# 3                   2        NaN
# 4                   2        NaN
# 5                   2        NaN
# 6                   2        NaN
# 7                   2        NaN
# 8                   2        NaN
# 9                   2        NaN
# 10                  2        NaN
# 11                  2        NaN
# 12                  2        NaN
# 13                  2        NaN
# 14                  2        NaN
# 15                  2        NaN
# 16                  2        NaN
# 17                  2        NaN
# 18                  2        NaN
# 19                  2        NaN
# 20                  2        NaN
# 21                  2        NaN
# 22                  2        NaN
# 23                  2        NaN
# 24                  2        NaN
# 25                  2        NaN
# 26                  2        NaN
# 27                  2        NaN
# 28                  2        NaN
# 29                  2        NaN
# ...               ...        ...
# 1026                1       2.55
# 1027                1       2.55
# 1028                1       2.55
# 1029                1       2.55
# 1030                1       2.55
# 1031                1       2.55
# 1032                1       2.55
# 1033                1       2.55
# 1034                1       2.55
# 1035                1       2.55
# 1036                1       2.55
# 1037                1       2.55
# 1038                1       2.55
# 1039                1       2.55
# 1040                1       2.55
# 1041                1       2.55
# 1042                1       2.55
# 1043                1       2.55
# 1044                1       2.55
# 1045                1       2.55
# 1046                1       2.55
# 1047                1       2.55
# 1048                1       2.55
# 1049                1       2.55
# 1050                1       2.55
# 1051                1       2.55
# 1052                1       2.55
# 1053                1       2.55
# 1054                1       2.55
# 1055                1        NaN
#
# [1056 rows x 10 columns]
