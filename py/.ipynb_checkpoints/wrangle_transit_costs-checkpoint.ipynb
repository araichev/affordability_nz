# %%
from pathlib import Path
import json
from functools import reduce
import math
import datetime as dt
import pytz 
from itertools import product
from collections import OrderedDict
import time
import re
import sys

import requests
import numpy as np
import pandas as pd
import geopandas as gpd
import shapely.ops as so

import helpers as hp

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Compute Auckland and Wellington fares through their web APIs

# %%
def get_journey_auckland(orig, dest, departure_time=None, max_walk=1600):
    """
    INPUT
    ------
    orig : list
        WGS84 longitude-latitude pair
    dest : list
        WGS84 longitude-latitude pair
    departure_time : string
        ISO 8601 datetime; e.g. '2017-06-01T07:30:00'
    max_walk : float
        Maximum walking distance in meters for the journey
        
    OUTPUT
    ------
    dictionary
        Decoded JSON response of journey
    """
    url = 'https://api.at.govt.nz/v2/public-restricted/journeyplanner/silverRailIVU/plan'
    fromLoc ='{!s},{!s}'.format(orig[1], orig[0])
    toLoc ='{!s},{!s}'.format(dest[1], dest[0])
    if departure_time is None:
        departure_time = dt.datetime.now().strftime('%Y-%m-%dT%H:%M:%S')
    date = departure_time + '+12:00'  # Add UTC offset
    params = {
        'from': 'from',
        'to': 'to',
        'fromLoc': fromLoc,
        'toLoc': toLoc,
        'timeMode': 'A',
        'date': date, 
        'modes': 'BUS,TRAIN,FERRY',
        'operators': '',
        'optimize': 'QUICK',
        'maxWalk': max_walk,
        'maxChanges': '-1',
        'routes': '',
        'subscription-key': '323741614c1c4b9083299adefe100aa6',
    }
    r = requests.get(url, params=params)
    
    # Raise an error if bad request
    r.raise_for_status()

    return r.json()         

def get_fare_auckland(journey):
    """
    Given a journey of the form output by :func:`get_journey_auckland`, 
    return the journey's adult fare (float)'
    """
    if journey['error'] is None:
        f = journey['response']['itineraries'][0]['fareHopAdult']
        if f is None:
            fare = 0
        else:
            fare = f/100
    else:
        fare = None
    return fare

def get_journey_wellington(orig, dest, departure_time=None, max_walk=1600):
    """
    INPUT
    ------
    orig : list
        WGS84 longitude-latitude pair
    dest : list
        WGS84 longitude-latitude pair
    departure_time : string
        ISO 8601 datetime; e.g. '2017-06-01T07:30:00'
    max_walk : float
        Maximum walking distance in meters for the journey
        
    OUTPUT
    ------
    text
        HTML response of journey query
    """
    url = 'https://www.metlink.org.nz/journeyplanner/JourneyPlannerForm'
    from_coords ='{!s},{!s}'.format(orig[1], orig[0])
    to_coords ='{!s},{!s}'.format(dest[1], dest[0])
    
    if departure_time is None:
        departure_time = dt.datetime.now().strftime('%Y-%m-%dT%H:%M:%S')
    date, time = departure_time.split('T')
        
    params = {
        'From': 'from',
        'To': 'to', 
        'Via': '',
        'When': 'LeaveAfter',
        'Date': date,
        'Time': time,
        'MaxChanges': 5,
        'WalkingSpeed': 4,
        'MaxWalking': max_walk,
        'Modes[Train]': 'Train',
        'Modes[Bus]': 'Bus',
        'Modes[Ferry]': 'Ferry',
        'Modes[Cable+Car]': 'Cable Car',
        'ShowAdvanced': '',
        'FromCoords': from_coords,
        'ToCoords': to_coords,
        'ViaCoords': '',
        'action_doForm': 'Go',
    }
    r = requests.get(url, params=params)
    # Raise an error if bad request
    r.raise_for_status()
    return r.text         

# Estimate Wellington card fare discount
path = hp.DATA_DIR/'wellington'/'transit_fares.csv'
f = pd.read_csv(path)
f['card/cash'] = f['card_fare']/f['cash_fare']
r = f['card/cash'].mean()
print('estimated Wellington card discount rate=', r)

def get_fare_wellington(journey, card_discount=r):
    """
    Given a journey of the form output by :func:`get_journey_wellington`, 
    extract the journey's adult cash fare (float), multiply it by the given
    discount rate to estimate the adult card fare, and return the result.
    """
    pattern = 'Total adult fare </span><strong>&#36;(\d+\.\d\d)</strong>'
    m = re.search(pattern, journey)
    if m:
        fare = float(m.group(1))
    else:
        fare = None
    return round(r*fare, 2)

def collect_fares(rental_points, departure_time, region):
    """
    """
    # Get all pairs of points excluding equal points
    f = rental_points[['rental_area', 'geometry']].copy()
    rows = [[o[0], o[1].coords[0], d[0], d[1].coords[0]] for o, d in product(f.values, f.values) if o[0] != d[0]]
    f = pd.DataFrame(rows, columns=['orig_name', 'orig', 'dest_name', 'dest'])

    if region == 'auckland':
        get_journey = get_journey_auckland
        get_fare = get_fare_auckland
        time_per_call = 3.6
    elif region == 'wellington':
        get_journey = get_journey_wellington
        get_fare = get_fare_wellington
        time_per_call = 2.4
    
    print('This will take about {:02f} minutes'.format(f.shape[0]*time_per_call/60))

    # Get journeys for each pair
    rows = []
    for __, row in f.iterrows():
        try:
            j = get_journey(row['orig'], row['dest'], departure_time=departure_time)
            fare = get_fare(j)
        except:
            fare = None
        rows.append([row['orig_name'], row['dest_name'], fare])

    g = pd.DataFrame(rows, columns=['orig_name', 'dest_name', 'card_fare'])
    return g
# Out:
# estimated Wellington card discount rate= 0.782401654073

# %%
# Test some
orig = [174.8151970336325, -36.89546015048722]  # Ellerslie
dest = [174.76864676675842, -36.84997406733503]  # Central east
# %time j = get_journey_auckland(orig, dest, departure_time='2017-07-17T07:30:00')
print(j)
get_fare_auckland(j)

# orig = (174.7708511352539,-41.28394744513899)
# dest = (174.78861808776855,-41.297458248607995)
# %time r = get_journey_wellington(orig, dest, departure_time='2017-06-01T07:30:00')
# r
# get_fare_wellington(r)
# Out:
# CPU times: user 12 ms, sys: 0 ns, total: 12 ms
# Wall time: 27.6 s
# {'error': None, 'status': 'OK', 'response': {'engine': 'silverRailIVU', 'itineraries': [{'duration': 2520000, 'startTimeStr': '7:32 am', 'endTimeStr': '8:14 am', 'durationStr': '42 minutes', 'fareWarnings': {}, 'fareError': None, 'fareChild': 300, 'fareAdult': 550, 'legs': [{'duration': 960000, 'stops': [], 'durationStr': '16 min', 'startLon': '174.815197', 'fareChild': 0, 'from': 'from', 'toStr': 'Walk to Ellerslie Train Station', 'endLon': '174.80811', 'legGeometry': {'length': 51, 'points': 'tce`F}q~i`@[lArVtKcHbYITKJBXAFE@CIBGHD\\zAnCgAFP'}, 'distanceStr': '1088 metres', 'mode': 'WALK', 'fareHopChild': 0, 'startTimeStr': '7:32 am', 'messages': [], 'endTimeStr': '7:48 am', 'isFirst': True, 'startLat': '-36.8954602', 'isFastLeg': False, 'fareAdult': 0, 'endLat': '-36.89847', 'distance': '1088 metres', 'fareHopTertiary': 0, 'startTime': '2017-07-17T07:32', 'isLast': False, 'endTime': '2017-07-17T07:48', 'distanceExact': 1088, 'to': 'Ellerslie Train Station', 'fareHopAdult': 0}, {'duration': 840000, 'stops': [{'geometry': {'encoded': False, 'data': [-36.89847, 174.80811], 'type': 'point'}, 'code': '112'}, {'geometry': {'encoded': False, 'data': [-36.86972, 174.77883], 'type': 'point'}, 'code': '115'}, {'geometry': {'encoded': False, 'data': [-36.84429, 174.76848], 'type': 'point'}, 'code': '133'}], 'durationStr': '14 min', 'startLon': '174.80811', 'fareChild': 300, 'from': 'Ellerslie Train Station', 'toStr': 'Train to Britomart Train Station', 'endLon': '174.76848', 'legGeometry': {'length': 1140, 'points': 'nve`Fue}i`@cKxDaEtCqFzGaIpN_MnUiKfT}IbSgF|JqFrIgNtOuZtYyGvFgHvDwGfBmEr@{GZyE_@EEsASoGiAo@GW@qAo@wA{@mFmEcCoCw@m@u@]aASWC}@?YBi@JkA`@uQlIsJjEi]~OiBp@_EfAcFbAsARm@?g@Ga@Ko@[[USUWa@Y_AMaAM_CGo@Qy@Q_@g@g@q@Y]EW?a@F[LULc@h@Q^Od@m@zBaHta@[xAU~BYrAgAtGc@V'}, 'distanceStr': 'undefined metres', 'mode': 'TRAIN', 'tripId': '51100070731-20170705140526_v55.10', 'fareHopChild': 0, 'provider': 'AM', 'startTimeStr': '7:48 am', 'messages': [], 'endTimeStr': '8:02 am', 'isFirst': False, 'startLat': '-36.89847', 'isFastLeg': True, 'fareAdult': 550, 'routeName': 'Onehunga Train Station to Britomart Train Station', 'endLat': '-36.84429', 'distance': 'undefined metres', 'fareHopTertiary': 0, 'startTime': '2017-07-17T07:48', 'isLast': False, 'endTime': '2017-07-17T08:02', 'routeCode': 'ONE', 'to': 'Britomart Train Station', 'fareHopAdult': 0}, {'duration': 720000, 'stops': [], 'durationStr': '12 min', 'startLon': '174.76848', 'fareChild': 0, 'from': 'Britomart Train Station', 'toStr': 'Walk to to', 'endLon': '174.7686468', 'legGeometry': {'length': 47, 'points': 'xc{_F_nui`@JDG`@xBj@VTVRzDjATCF@E\\|@VBLD@JDPk@rBXzAZN@|@UDOfA{@ZQXa@\\OJGPS^Qz@QhAP_@cACQDe@b@N'}, 'distanceStr': '800 metres', 'mode': 'WALK', 'fareHopChild': 0, 'startTimeStr': '8:02 am', 'messages': [], 'endTimeStr': '8:14 am', 'isFirst': False, 'startLat': '-36.84429', 'isFastLeg': False, 'fareAdult': 0, 'endLat': '-36.8499741', 'distance': '800 metres', 'fareHopTertiary': 0, 'startTime': '2017-07-17T08:02', 'isLast': True, 'endTime': '2017-07-17T08:14', 'distanceExact': 800, 'to': 'to', 'fareHopAdult': 0}], 'fareHopTertiary': 235, 'startTime': '2017-07-17T07:32', 'endTime': '2017-07-17T08:14', 'fareHopAdult': 315, 'fareHopChild': 180}, {'duration': 2700000, 'startTimeStr': '7:37 am', 'endTimeStr': '8:22 am', 'durationStr': 'an hour', 'fareWarnings': {}, 'fareError': None, 'fareChild': 300, 'fareAdult': 550, 'legs': [{'duration': 960000, 'stops': [], 'durationStr': '16 min', 'startLon': '174.815197', 'fareChild': 0, 'from': 'from', 'toStr': 'Walk to Ellerslie Train Station', 'endLon': '174.80811', 'legGeometry': {'length': 51, 'points': 'tce`F}q~i`@[lArVtKcHbYITKJBXAFE@CIBGHD\\zAnCgAFP'}, 'distanceStr': '1088 metres', 'mode': 'WALK', 'fareHopChild': 0, 'startTimeStr': '7:37 am', 'messages': [], 'endTimeStr': '7:53 am', 'isFirst': True, 'startLat': '-36.8954602', 'isFastLeg': False, 'fareAdult': 0, 'endLat': '-36.89847', 'distance': '1088 metres', 'fareHopTertiary': 0, 'startTime':  ...
# 5.5

# %%
for x in j['response']['itineraries']:
    print(x['startTimeStr'], x['fareHopAdult'], [y['mode'] for y in x['legs']], 
      [y['toStr'] for y in x['legs'] if 'toStr' in y])
# Out:
# 7:32 am 315 ['WALK', 'TRAIN', 'WALK'] ['Walk to Ellerslie Train Station', 'Train to Britomart Train Station', 'Walk to to']
# 7:37 am 315 ['WALK', 'TRAIN', 'WALK'] ['Walk to Ellerslie Train Station', 'Train to Britomart Train Station', 'Walk to to']
# 7:47 am 315 ['WALK', 'BUS', 'WALK'] ['Walk to Ellerslie Panmure Hwy and Ellerslie Park, 243 Ellerslie Panmure Hwy', 'Bus to Universities, 25 Symonds St', 'Walk to to']
# 7:56 am 315 ['WALK', 'BUS', 'WALK'] ['Walk to Ellerslie Panmure Hwy and Ellerslie Park, 243 Ellerslie Panmure Hwy', 'Bus to Universities, 25 Symonds St', 'Walk to to']
# 8:02 am 315 ['WALK', 'TRAIN', 'WALK'] ['Walk to Ellerslie Train Station', 'Train to Britomart Train Station', 'Walk to to']
# 8:06 am 315 ['WALK', 'BUS', 'WALK', 'TRAIN', 'WALK'] ['Walk to Amy St and Ballin, 32 Amy St', 'Bus to Ellerslie, 95 Main Hwy', 'Walk to Ellerslie Train Station', 'Train to Britomart Train Station', 'Walk to to']
# 8:07 am 315 ['WALK', 'TRAIN', 'WALK'] ['Walk to Ellerslie Train Station', 'Train to Britomart Train Station', 'Walk to to']
# 8:09 am 315 ['WALK', 'BUS', 'BUS', 'WALK'] ['Walk to Main Hwy near Cawley St', 'Bus to Newmarket, 277 Broadway', 'Bus to Beach Rd and Churchill, Beach Rd near Stanley St', 'Walk to to']
# 8:11 am 315 ['WALK', 'BUS', 'WALK'] ['Walk to Ellerslie Panmure Hwy and Ellerslie Park, 243 Ellerslie Panmure Hwy', 'Bus to Universities, 25 Symonds St', 'Walk to to']
# 8:17 am 315 ['WALK', 'TRAIN', 'WALK'] ['Walk to Ellerslie Train Station', 'Train to Britomart Train Station', 'Walk to to']
# 8:24 am 315 ['WALK', 'BUS', 'BUS', 'WALK'] ['Walk to Amy St and Ballin, 32 Amy St', 'Bus to Newmarket, 277 Broadway', 'Bus to Beach Rd and Churchill, Beach Rd near Stanley St', 'Walk to to']

# %%
j
# Out:
# {'error': None,
#  'response': {'engine': 'silverRailIVU',
#   'itineraries': [{'duration': 2700000,
#     'durationStr': 'an hour',
#     'endTime': '2017-07-10T17:08',
#     'endTimeStr': '5:08 pm',
#     'fareAdult': 700,
#     'fareChild': 400,
#     'fareError': None,
#     'fareHopAdult': 315,
#     'fareHopChild': 180,
#     'fareHopTertiary': 235,
#     'fareWarnings': {},
#     'legs': [{'distance': '547 metres',
#       'distanceExact': 547,
#       'distanceStr': '547 metres',
#       'duration': 480000,
#       'durationStr': '8 min',
#       'endLat': '-36.89938',
#       'endLon': '174.81355',
#       'endTime': '2017-07-10T16:31',
#       'endTimeStr': '4:31 pm',
#       'fareAdult': 0,
#       'fareChild': 0,
#       'fareHopAdult': 0,
#       'fareHopChild': 0,
#       'fareHopTertiary': 0,
#       'from': 'from',
#       'isFastLeg': False,
#       'isFirst': True,
#       'isLast': False,
#       'legGeometry': {'length': 18,
#        'points': 'tce`F}q~i`@[lAdTnJHc@TI`@WVW\\?BWF?'},
#       'messages': [],
#       'mode': 'WALK',
#       'startLat': '-36.8954602',
#       'startLon': '174.815197',
#       'startTime': '2017-07-10T16:23',
#       'startTimeStr': '4:23 pm',
#       'stops': [],
#       'to': 'Main Hwy near Cawley St',
#       'toStr': 'Walk to Main Hwy near Cawley St'},
#      {'distance': 'undefined metres',
#       'distanceStr': 'undefined metres',
#       'duration': 840000,
#       'durationStr': '14 min',
#       'endLat': '-36.87072',
#       'endLon': '174.7772',
#       'endTime': '2017-07-10T16:45',
#       'endTimeStr': '4:45 pm',
#       'fareAdult': 350,
#       'fareChild': 200,
#       'fareHopAdult': 0,
#       'fareHopChild': 0,
#       'fareHopTertiary': 0,
#       'from': 'Main Hwy near Cawley St',
#       'isFastLeg': False,
#       'isFirst': False,
#       'isLast': False,
#       'legGeometry': {'length': 213,
#        'points': 'b|e`Fug~i`@I?Kx@sBlIJDKEqDxNETFBECC@UbAMZMFO@oB]yASO@IJG`@@\\fBzHFd@?\\Gf@U~@HDIEgFtSFBGCoD`OC\\BPJRYf@uArAUPa@j@wDxFHLIMgI~LgEfGeBnCABFFGGmFdIGJBHCIaHjK}AhBFFGGuHbIDHEIyH~HsAdABJCKgSvOBHCImAbAUXwIvLFHGIiKzNe@v@aEHM@?L?MoJR?R?SiDFg@G}Cs@CP'},
#       'messages': [],
#       'mode': 'BUS',
#       'provider': 'NZBML',
#       'routeCode': '505',
#       'routeName': 'Sylvia Park to Britomart via Ruawai Rd and Ellerslie',
#       'startLat': '-36.89938',
#       'startLon': '174.81355',
#       'startTime': '2017-07-10T16:31',
#       'startTimeStr': '4:31 pm',
#       'stops': [{'code': '7509',
#         'geometry': {'data': [-36.89938, 174.81355],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '1501',
#         'geometry': {'data': [-36.89875, 174.81156],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '7505',
#         'geometry': {'data': [-36.89781, 174.80893],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '7503',
#         'geometry': {'data': [-36.89672, 174.8058],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '7501',
#         'geometry': {'data': [-36.89555, 174.8025],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '7615',
#         'geometry': {'data': [-36.89298, 174.79736],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '7613',
#         'geometry': {'data': [-36.88981, 174.79309],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '7611',
#         'geometry': {'data': [-36.88856, 174.79139],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '7609',
#         'geometry': {'data': [-36.88665, 174.78889],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '7607',
#         'geometry': {'data': [-36.8851, 174.78726],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '7605',
#         'geometry': {'data': [-36.8831, 174.7853],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '8480',
#         'geometry': {'data': [-36.87986, 174.78263],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '7601',
#         'geometry': {'data': [-36.87766, 174.77996],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '7207',
#         'geometry': {'data': [-36.87442, 174.77706],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '7205',
#         'geometry': {'data': [-36.87258, 174.77693],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '7203',
#         'geometry': {'data': [-36.87072, 174.7772],
#          'encoded': False,
#          'type': 'point'}}],
#       'to': 'Newmarket, 277 Broadway',
#       'toStr': 'Bus to Newmarket, 277 Broadway',
#       'tripId': '5505058328-20170602141618_v54.27'},
#      {'distance': 'undefined metres',
#       'distanceStr': 'undefined metres',
#       'duration': 660000,
#       'durationStr': '11 min',
#       'endLat': '-36.85078',
#       'endLon': '174.77161',
#       'endTime': '2017-07-10T17:02',
#       'endTimeStr': '5:02 pm',
#       'fareAdult': 350,
#       'fareChild': 200,
#       'fareHopAdult': 0,
#       'fareHopChild': 0,
#       'fareHopTertiary': 0,
#       'from': 'Newmarket, 277 Broadway',
#       'isFastLeg': False,
#       'isFirst': False,
#       'isLast': False,
#       'legGeometry': {'length': 156,
#        'points': '~h``Fodwi`@BQsMsCWCg@BQCEVDWaAYsCvTJBKCoDfYcCk@AL?M_GoAQCU?cCl@_AVWJkCp@_Cr@QHWVOd@a@rCFDGEERkAzIK`@sK|SM`@y@c@QOsBkCKJJKo@y@_FmFeGiHcBwAELDMuBoB_HaHuB{BiDwEIJ'},
#       'messages': [],
#       'mode': 'BUS',
#       'provider': 'NZBML',
#       'routeCode': '322',
#       'routeName': 'Otahuhu Station to Britomart via Great South Road',
#       'startLat': '-36.87072',
#       'startLon': '174.7772',
#       'startTime': '2017-07-10T16:51',
#       'startTimeStr': '4:51 pm',
#       'stops': [{'code': '7203',
#         'geometry': {'data': [-36.87072, 174.7772],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '7201',
#         'geometry': {'data': [-36.86796, 174.77793],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '7177',
#         'geometry': {'data': [-36.86698, 174.77468],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '7231',
#         'geometry': {'data': [-36.86537, 174.77065],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '7227',
#         'geometry': {'data': [-36.86103, 174.76909],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '7149',
#         'geometry': {'data': [-36.85741, 174.76449],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '7147',
#         'geometry': {'data': [-36.85427, 174.76789],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '7145',
#         'geometry': {'data': [-36.85078, 174.77161],
#          'encoded': False,
#          'type': 'point'}}],
#       'to': 'Symonds St and Waterloo, 3 Symonds St',
#       'toStr': 'Bus to Symonds St and Waterloo, 3 Symonds St',
#       'tripId': '14322062753-20170602141618_v54.27'},
#      {'distance': '416 metres',
#       'distanceExact': 416,
#       'distanceStr': '416 metres',
#       'duration': 360000,
#       'durationStr': '6 min',
#       'endLat': '-36.8499741',
#       'endLon': '174.7686468',
#       'endTime': '2017-07-10T17:08',
#       'endTimeStr': '5:08 pm',
#       'fareAdult': 0,
#       'fareChild': 0,
#       'fareHopAdult': 0,
#       'fareHopChild': 0,
#       'fareHopTertiary': 0,
#       'from': 'Symonds St and Waterloo, 3 Symonds St',
#       'isFastLeg': False,
#       'isFirst': False,
#       'isLast': True,
#       'legGeometry': {'length': 23,
#        'points': 'jl|_Fqavi`@BENFlBfC_B|BX^wAxBFN@V_@vAc@OWrAq@S'},
#       'messages': [],
#       'mode': 'WALK',
#       'startLat': '-36.85078',
#       'startLon': '174.77161',
#       'startTime': '2017-07-10T17:02',
#       'startTimeStr': '5:02 pm',
#       'stops': [],
#       'to': 'to',
#       'toStr': 'Walk to to'}],
#     'startTime': '2017-07-10T16:23',
#     'startTimeStr': '4:23 pm'},
#    {'duration': 2760000,
#     'durationStr': 'an hour',
#     'endTime': '2017-07-10T17:12',
#     'endTimeStr': '5:12 pm',
#     'fareAdult': 550,
#     'fareChild': 300,
#     'fareError': None,
#     'fareHopAdult': 315,
#     'fareHopChild': 180,
#     'fareHopTertiary': 235,
#     'fareWarnings': {},
#     'legs': [{'distance': '1088 metres',
#       'distanceExact': 1088,
#       'distanceStr': '1088 metres',
#       'duration': 960000,
#       'durationStr': '16 min',
#       'endLat': '-36.89847',
#       'endLon': '174.80811',
#       'endTime': '2017-07-10T16:42',
#       'endTimeStr': '4:42 pm',
#       'fareAdult': 0,
#       'fareChild': 0,
#       'fareHopAdult': 0,
#       'fareHopChild': 0,
#       'fareHopTertiary': 0,
#       'from': 'from',
#       'isFastLeg': False,
#       'isFirst': True,
#       'isLast': False,
#       'legGeometry': {'length': 51,
#        'points': 'tce`F}q~i`@[lArVtKcHbYITKJBXAFE@CIBGHD\\zAnCgAFP'},
#       'messages': [],
#       'mode': 'WALK',
#       'startLat': '-36.8954602',
#       'startLon': '174.815197',
#       'startTime': '2017-07-10T16:26',
#       'startTimeStr': '4:26 pm',
#       'stops': [],
#       'to': 'Ellerslie Train Station',
#       'toStr': 'Walk to Ellerslie Train Station'},
#      {'distance': 'undefined metres',
#       'distanceStr': 'undefined metres',
#       'duration': 1080000,
#       'durationStr': '18 min',
#       'endLat': '-36.84429',
#       'endLon': '174.76848',
#       'endTime': '2017-07-10T17:00',
#       'endTimeStr': '5:00 pm',
#       'fareAdult': 550,
#       'fareChild': 300,
#       'fareHopAdult': 0,
#       'fareHopChild': 0,
#       'fareHopTertiary': 0,
#       'from': 'Ellerslie Train Station',
#       'isFastLeg': True,
#       'isFirst': False,
#       'isLast': False,
#       'legGeometry': {'length': 715,
#        'points': 'nve`Fue}i`@CIuAl@g@\\kHnCsCxBeBfBaArAuAdByC|EwC`GO^wDnHwEhIuElJBB}AzCcGzLuDzIyAvDeEtH{BtDm@v@]j@uGvHaJjJCAg@d@}H`IoQzO}AlA}@l@kCzAiBx@aBj@sCp@mB\\qBT}CPsALkA?c@CsC]_NaCgEqCqFaFcAiAgAq@u@S_@GsAGu@DcAZmr@r[aKdEsIdCeDl@kAJsAWoAo@y@gBSeAGqAQeB[gAYe@w@i@o@Os@HgAh@k@nAq@rC}Mnt@'},
#       'messages': [],
#       'mode': 'TRAIN',
#       'provider': 'AM',
#       'routeCode': 'STH',
#       'routeName': 'Papakura Train Station to Britomart Train Station',
#       'startLat': '-36.89847',
#       'startLon': '174.80811',
#       'startTime': '2017-07-10T16:42',
#       'startTimeStr': '4:42 pm',
#       'stops': [{'code': '112',
#         'geometry': {'data': [-36.89847, 174.80811],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '113',
#         'geometry': {'data': [-36.88966, 174.79742],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '114',
#         'geometry': {'data': [-36.88138, 174.78542],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '115',
#         'geometry': {'data': [-36.86972, 174.77883],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '140',
#         'geometry': {'data': [-36.85473, 174.7774],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '133',
#         'geometry': {'data': [-36.84429, 174.76848],
#          'encoded': False,
#          'type': 'point'}}],
#       'to': 'Britomart Train Station',
#       'toStr': 'Train to Britomart Train Station',
#       'tripId': '23100071234-20170602141618_v54.27'},
#      {'distance': '800 metres',
#       'distanceExact': 800,
#       'distanceStr': '800 metres',
#       'duration': 720000,
#       'durationStr': '12 min',
#       'endLat': '-36.8499741',
#       'endLon': '174.7686468',
#       'endTime': '2017-07-10T17:12',
#       'endTimeStr': '5:12 pm',
#       'fareAdult': 0,
#       'fareChild': 0,
#       'fareHopAdult': 0,
#       'fareHopChild': 0,
#       'fareHopTertiary': 0,
#       'from': 'Britomart Train Station',
#       'isFastLeg': False,
#       'isFirst': False,
#       'isLast': True,
#       'legGeometry': {'length': 47,
#        'points': 'xc{_F_nui`@JDG`@xBj@VTVRzDjATCF@E\\|@VBLD@JDPk@rBXzAZN@|@UDOfA{@ZQXa@\\OJGPS^Qz@QhAP_@cACQDe@b@N'},
#       'messages': [],
#       'mode': 'WALK',
#       'startLat': '-36.84429',
#       'startLon': '174.76848',
#       'startTime': '2017-07-10T17:00',
#       'startTimeStr': '5:00 pm',
#       'stops': [],
#       'to': 'to',
#       'toStr': 'Walk to to'}],
#     'startTime': '2017-07-10T16:26',
#     'startTimeStr': '4:26 pm'},
#    {'duration': 2520000,
#     'durationStr': '42 minutes',
#     'endTime': '2017-07-10T17:14',
#     'endTimeStr': '5:14 pm',
#     'fareAdult': 550,
#     'fareChild': 300,
#     'fareError': None,
#     'fareHopAdult': 315,
#     'fareHopChild': 180,
#     'fareHopTertiary': 235,
#     'fareWarnings': {},
#     'legs': [{'distance': '1088 metres',
#       'distanceExact': 1088,
#       'distanceStr': '1088 metres',
#       'duration': 960000,
#       'durationStr': '16 min',
#       'endLat': '-36.89847',
#       'endLon': '174.80811',
#       'endTime': '2017-07-10T16:48',
#       'endTimeStr': '4:48 pm',
#       'fareAdult': 0,
#       'fareChild': 0,
#       'fareHopAdult': 0,
#       'fareHopChild': 0,
#       'fareHopTertiary': 0,
#       'from': 'from',
#       'isFastLeg': False,
#       'isFirst': True,
#       'isLast': False,
#       'legGeometry': {'length': 51,
#        'points': 'tce`F}q~i`@[lArVtKcHbYITKJBXAFE@CIBGHD\\zAnCgAFP'},
#       'messages': [],
#       'mode': 'WALK',
#       'startLat': '-36.8954602',
#       'startLon': '174.815197',
#       'startTime': '2017-07-10T16:32',
#       'startTimeStr': '4:32 pm',
#       'stops': [],
#       'to': 'Ellerslie Train Station',
#       'toStr': 'Walk to Ellerslie Train Station'},
#      {'distance': 'undefined metres',
#       'distanceStr': 'undefined metres',
#       'duration': 840000,
#       'durationStr': '14 min',
#       'endLat': '-36.84429',
#       'endLon': '174.76848',
#       'endTime': '2017-07-10T17:02',
#       'endTimeStr': '5:02 pm',
#       'fareAdult': 550,
#       'fareChild': 300,
#       'fareHopAdult': 0,
#       'fareHopChild': 0,
#       'fareHopTertiary': 0,
#       'from': 'Ellerslie Train Station',
#       'isFastLeg': True,
#       'isFirst': False,
#       'isLast': False,
#       'legGeometry': {'length': 1140,
#        'points': 'nve`Fue}i`@cKxDaEtCqFzGaIpN_MnUiKfT}IbSgF|JqFrIgNtOuZtYyGvFgHvDwGfBmEr@{GZyE_@EEsASoGiAo@GW@qAo@wA{@mFmEcCoCw@m@u@]aASWC}@?YBi@JkA`@uQlIsJjEi]~OiBp@_EfAcFbAsARm@?g@Ga@Ko@[[USUWa@Y_AMaAM_CGo@Qy@Q_@g@g@q@Y]EW?a@F[LULc@h@Q^Od@m@zBaHta@[xAU~BYrAgAtGc@V'},
#       'messages': [],
#       'mode': 'TRAIN',
#       'provider': 'AM',
#       'routeCode': 'ONE',
#       'routeName': 'Onehunga Train Station to Britomart Train Station',
#       'startLat': '-36.89847',
#       'startLon': '174.80811',
#       'startTime': '2017-07-10T16:48',
#       'startTimeStr': '4:48 pm',
#       'stops': [{'code': '112',
#         'geometry': {'data': [-36.89847, 174.80811],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '115',
#         'geometry': {'data': [-36.86972, 174.77883],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '133',
#         'geometry': {'data': [-36.84429, 174.76848],
#          'encoded': False,
#          'type': 'point'}}],
#       'to': 'Britomart Train Station',
#       'toStr': 'Train to Britomart Train Station',
#       'tripId': '51100070768-20170602141618_v54.27'},
#      {'distance': '800 metres',
#       'distanceExact': 800,
#       'distanceStr': '800 metres',
#       'duration': 720000,
#       'durationStr': '12 min',
#       'endLat': '-36.8499741',
#       'endLon': '174.7686468',
#       'endTime': '2017-07-10T17:14',
#       'endTimeStr': '5:14 pm',
#       'fareAdult': 0,
#       'fareChild': 0,
#       'fareHopAdult': 0,
#       'fareHopChild': 0,
#       'fareHopTertiary': 0,
#       'from': 'Britomart Train Station',
#       'isFastLeg': False,
#       'isFirst': False,
#       'isLast': True,
#       'legGeometry': {'length': 47,
#        'points': 'xc{_F_nui`@JDG`@xBj@VTVRzDjATCF@E\\|@VBLD@JDPk@rBXzAZN@|@UDOfA{@ZQXa@\\OJGPS^Qz@QhAP_@cACQDe@b@N'},
#       'messages': [],
#       'mode': 'WALK',
#       'startLat': '-36.84429',
#       'startLon': '174.76848',
#       'startTime': '2017-07-10T17:02',
#       'startTimeStr': '5:02 pm',
#       'stops': [],
#       'to': 'to',
#       'toStr': 'Walk to to'}],
#     'startTime': '2017-07-10T16:32',
#     'startTimeStr': '4:32 pm'},
#    {'duration': 2700000,
#     'durationStr': 'an hour',
#     'endTime': '2017-07-10T17:22',
#     'endTimeStr': '5:22 pm',
#     'fareAdult': 550,
#     'fareChild': 300,
#     'fareError': None,
#     'fareHopAdult': 315,
#     'fareHopChild': 180,
#     'fareHopTertiary': 235,
#     'fareWarnings': {},
#     'legs': [{'distance': '1088 metres',
#       'distanceExact': 1088,
#       'distanceStr': '1088 metres',
#       'duration': 960000,
#       'durationStr': '16 min',
#       'endLat': '-36.89847',
#       'endLon': '174.80811',
#       'endTime': '2017-07-10T16:53',
#       'endTimeStr': '4:53 pm',
#       'fareAdult': 0,
#       'fareChild': 0,
#       'fareHopAdult': 0,
#       'fareHopChild': 0,
#       'fareHopTertiary': 0,
#       'from': 'from',
#       'isFastLeg': False,
#       'isFirst': True,
#       'isLast': False,
#       'legGeometry': {'length': 51,
#        'points': 'tce`F}q~i`@[lArVtKcHbYITKJBXAFE@CIBGHD\\zAnCgAFP'},
#       'messages': [],
#       'mode': 'WALK',
#       'startLat': '-36.8954602',
#       'startLon': '174.815197',
#       'startTime': '2017-07-10T16:37',
#       'startTimeStr': '4:37 pm',
#       'stops': [],
#       'to': 'Ellerslie Train Station',
#       'toStr': 'Walk to Ellerslie Train Station'},
#      {'distance': 'undefined metres',
#       'distanceStr': 'undefined metres',
#       'duration': 1020000,
#       'durationStr': '17 min',
#       'endLat': '-36.84429',
#       'endLon': '174.76848',
#       'endTime': '2017-07-10T17:10',
#       'endTimeStr': '5:10 pm',
#       'fareAdult': 550,
#       'fareChild': 300,
#       'fareHopAdult': 0,
#       'fareHopChild': 0,
#       'fareHopTertiary': 0,
#       'from': 'Ellerslie Train Station',
#       'isFastLeg': True,
#       'isFirst': False,
#       'isLast': False,
#       'legGeometry': {'length': 715,
#        'points': 'nve`Fue}i`@CIuAl@g@\\kHnCsCxBeBfBaArAuAdByC|EwC`GO^wDnHwEhIuElJBB}AzCcGzLuDzIyAvDeEtH{BtDm@v@]j@uGvHaJjJCAg@d@}H`IoQzO}AlA}@l@kCzAiBx@aBj@sCp@mB\\qBT}CPsALkA?c@CsC]_NaCgEqCqFaFcAiAgAq@u@S_@GsAGu@DcAZmr@r[aKdEsIdCeDl@kAJsAWoAo@y@gBSeAGqAQeB[gAYe@w@i@o@Os@HgAh@k@nAq@rC}Mnt@'},
#       'messages': [],
#       'mode': 'TRAIN',
#       'provider': 'AM',
#       'routeCode': 'STH',
#       'routeName': 'Papakura Train Station to Britomart Train Station',
#       'startLat': '-36.89847',
#       'startLon': '174.80811',
#       'startTime': '2017-07-10T16:53',
#       'startTimeStr': '4:53 pm',
#       'stops': [{'code': '112',
#         'geometry': {'data': [-36.89847, 174.80811],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '113',
#         'geometry': {'data': [-36.88966, 174.79742],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '114',
#         'geometry': {'data': [-36.88138, 174.78542],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '115',
#         'geometry': {'data': [-36.86972, 174.77883],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '140',
#         'geometry': {'data': [-36.85473, 174.7774],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '133',
#         'geometry': {'data': [-36.84429, 174.76848],
#          'encoded': False,
#          'type': 'point'}}],
#       'to': 'Britomart Train Station',
#       'toStr': 'Train to Britomart Train Station',
#       'tripId': '23100071236-20170602141618_v54.27'},
#      {'distance': '800 metres',
#       'distanceExact': 800,
#       'distanceStr': '800 metres',
#       'duration': 720000,
#       'durationStr': '12 min',
#       'endLat': '-36.8499741',
#       'endLon': '174.7686468',
#       'endTime': '2017-07-10T17:22',
#       'endTimeStr': '5:22 pm',
#       'fareAdult': 0,
#       'fareChild': 0,
#       'fareHopAdult': 0,
#       'fareHopChild': 0,
#       'fareHopTertiary': 0,
#       'from': 'Britomart Train Station',
#       'isFastLeg': False,
#       'isFirst': False,
#       'isLast': True,
#       'legGeometry': {'length': 47,
#        'points': 'xc{_F_nui`@JDG`@xBj@VTVRzDjATCF@E\\|@VBLD@JDPk@rBXzAZN@|@UDOfA{@ZQXa@\\OJGPS^Qz@QhAP_@cACQDe@b@N'},
#       'messages': [],
#       'mode': 'WALK',
#       'startLat': '-36.84429',
#       'startLon': '174.76848',
#       'startTime': '2017-07-10T17:10',
#       'startTimeStr': '5:10 pm',
#       'stops': [],
#       'to': 'to',
#       'toStr': 'Walk to to'}],
#     'startTime': '2017-07-10T16:37',
#     'startTimeStr': '4:37 pm'},
#    {'duration': 2820000,
#     'durationStr': 'an hour',
#     'endTime': '2017-07-10T17:29',
#     'endTimeStr': '5:29 pm',
#     'fareAdult': 550,
#     'fareChild': 300,
#     'fareError': None,
#     'fareHopAdult': 315,
#     'fareHopChild': 180,
#     'fareHopTertiary': 235,
#     'fareWarnings': {},
#     'legs': [{'distance': '135 metres',
#       'distanceExact': 135,
#       'distanceStr': '135 metres',
#       'duration': 120000,
#       'durationStr': '1 min',
#       'endLat': '-36.89611',
#       'endLon': '174.81445',
#       'endTime': '2017-07-10T16:44',
#       'endTimeStr': '4:44 pm',
#       'fareAdult': 0,
#       'fareChild': 0,
#       'fareHopAdult': 0,
#       'fareHopChild': 0,
#       'fareHopTertiary': 0,
#       'from': 'from',
#       'isFastLeg': False,
#       'isFirst': True,
#       'isLast': False,
#       'legGeometry': {'length': 5, 'points': 'tce`F}q~i`@[lAvCpABK'},
#       'messages': [],
#       'mode': 'WALK',
#       'startLat': '-36.8954602',
#       'startLon': '174.815197',
#       'startTime': '2017-07-10T16:42',
#       'startTimeStr': '4:42 pm',
#       'stops': [],
#       'to': 'Amy St and Ballin, 32 Amy St',
#       'toStr': 'Walk to Amy St and Ballin, 32 Amy St'},
#      {'distance': 'undefined metres',
#       'distanceStr': 'undefined metres',
#       'duration': 2340000,
#       'durationStr': '39 min',
#       'endLat': '-36.85078',
#       'endLon': '174.77161',
#       'endTime': '2017-07-10T17:23',
#       'endTimeStr': '5:23 pm',
#       'fareAdult': 550,
#       'fareChild': 300,
#       'fareHopAdult': 0,
#       'fareHopChild': 0,
#       'fareHopTertiary': 0,
#       'from': 'Amy St and Ballin, 32 Amy St',
#       'isFastLeg': False,
#       'isFirst': False,
#       'isLast': False,
#       'legGeometry': {'length': 368,
#        'points': 'tge`Fim~i`@CHnB~@vJjEpBv@qAlFJDKEqDxNETFBECC@UbAMZMFO@oB]yASO@IJG`@@\\fBzHFd@?\\Gf@U~@HDIEgFtSFBGCoD`OC\\BPJRYf@uArAUPa@j@wDxFHLIMgI~LgEfGeBnCABFFGGmFdIGJBHCIaHjK}AhBFFGGuHbIDHEIyH~HsAdABJCKgSvOBHCImAbAUXwIvLFHGIiKzNe@v@aEHM@?L?MoJR?R?SiDFg@G}Cs@CPBQsMsCWCg@BQCEVDWaAYsCvTJBKCoDfYcCk@AL?M_GoAQCU?cCl@_AVWJkCp@_Cr@QHWVOd@a@rCFDGEERkAzIK`@sK|SM`@y@c@QOsBkCKJJKo@y@_FmFeGiHcBwAELDMuBoB_HaHuB{BiDwEIJ'},
#       'messages': [],
#       'mode': 'BUS',
#       'provider': 'NZBML',
#       'routeCode': '595',
#       'routeName': 'Glen Innes Centre To Britomart Via Panmure And Ellerslie',
#       'startLat': '-36.89611',
#       'startLon': '174.81445',
#       'startTime': '2017-07-10T16:44',
#       'startTimeStr': '4:44 pm',
#       'stops': [{'code': '7463',
#         'geometry': {'data': [-36.89611, 174.81445],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '1501',
#         'geometry': {'data': [-36.89875, 174.81156],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '7505',
#         'geometry': {'data': [-36.89781, 174.80893],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '7503',
#         'geometry': {'data': [-36.89672, 174.8058],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '7501',
#         'geometry': {'data': [-36.89555, 174.8025],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '7615',
#         'geometry': {'data': [-36.89298, 174.79736],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '7613',
#         'geometry': {'data': [-36.88981, 174.79309],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '7611',
#         'geometry': {'data': [-36.88856, 174.79139],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '7609',
#         'geometry': {'data': [-36.88665, 174.78889],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '7607',
#         'geometry': {'data': [-36.8851, 174.78726],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '7605',
#         'geometry': {'data': [-36.8831, 174.7853],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '8480',
#         'geometry': {'data': [-36.87986, 174.78263],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '7601',
#         'geometry': {'data': [-36.87766, 174.77996],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '7207',
#         'geometry': {'data': [-36.87442, 174.77706],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '7205',
#         'geometry': {'data': [-36.87258, 174.77693],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '7203',
#         'geometry': {'data': [-36.87072, 174.7772],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '7201',
#         'geometry': {'data': [-36.86796, 174.77793],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '7177',
#         'geometry': {'data': [-36.86698, 174.77468],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '7231',
#         'geometry': {'data': [-36.86537, 174.77065],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '7227',
#         'geometry': {'data': [-36.86103, 174.76909],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '7149',
#         'geometry': {'data': [-36.85741, 174.76449],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '7147',
#         'geometry': {'data': [-36.85427, 174.76789],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '7145',
#         'geometry': {'data': [-36.85078, 174.77161],
#          'encoded': False,
#          'type': 'point'}}],
#       'to': 'Symonds St and Waterloo, 3 Symonds St',
#       'toStr': 'Bus to Symonds St and Waterloo, 3 Symonds St',
#       'tripId': '14595039913-20170602141618_v54.27'},
#      {'distance': '416 metres',
#       'distanceExact': 416,
#       'distanceStr': '416 metres',
#       'duration': 360000,
#       'durationStr': '6 min',
#       'endLat': '-36.8499741',
#       'endLon': '174.7686468',
#       'endTime': '2017-07-10T17:29',
#       'endTimeStr': '5:29 pm',
#       'fareAdult': 0,
#       'fareChild': 0,
#       'fareHopAdult': 0,
#       'fareHopChild': 0,
#       'fareHopTertiary': 0,
#       'from': 'Symonds St and Waterloo, 3 Symonds St',
#       'isFastLeg': False,
#       'isFirst': False,
#       'isLast': True,
#       'legGeometry': {'length': 23,
#        'points': 'jl|_Fqavi`@BENFlBfC_B|BX^wAxBFN@V_@vAc@OWrAq@S'},
#       'messages': [],
#       'mode': 'WALK',
#       'startLat': '-36.85078',
#       'startLon': '174.77161',
#       'startTime': '2017-07-10T17:23',
#       'startTimeStr': '5:23 pm',
#       'stops': [],
#       'to': 'to',
#       'toStr': 'Walk to to'}],
#     'startTime': '2017-07-10T16:42',
#     'startTimeStr': '4:42 pm'},
#    {'duration': 2700000,
#     'durationStr': 'an hour',
#     'endTime': '2017-07-10T17:32',
#     'endTimeStr': '5:32 pm',
#     'fareAdult': 550,
#     'fareChild': 300,
#     'fareError': None,
#     'fareHopAdult': 315,
#     'fareHopChild': 180,
#     'fareHopTertiary': 235,
#     'fareWarnings': {},
#     'legs': [{'distance': '614 metres',
#       'distanceExact': 614,
#       'distanceStr': '614 metres',
#       'duration': 540000,
#       'durationStr': '9 min',
#       'endLat': '-36.89875',
#       'endLon': '174.81156',
#       'endTime': '2017-07-10T16:56',
#       'endTimeStr': '4:56 pm',
#       'fareAdult': 0,
#       'fareChild': 0,
#       'fareHopAdult': 0,
#       'fareHopChild': 0,
#       'fareHopTertiary': 0,
#       'from': 'from',
#       'isFastLeg': False,
#       'isFirst': True,
#       'isLast': False,
#       'legGeometry': {'length': 15, 'points': 'tce`F}q~i`@[lArVtKsAjFJD'},
#       'messages': [],
#       'mode': 'WALK',
#       'startLat': '-36.8954602',
#       'startLon': '174.815197',
#       'startTime': '2017-07-10T16:47',
#       'startTimeStr': '4:47 pm',
#       'stops': [],
#       'to': 'Main Hwy and Amy, 153 Main Hwy',
#       'toStr': 'Walk to Main Hwy and Amy, 153 Main Hwy'},
#      {'distance': 'undefined metres',
#       'distanceStr': 'undefined metres',
#       'duration': 1800000,
#       'durationStr': '30 min',
#       'endLat': '-36.85078',
#       'endLon': '174.77161',
#       'endTime': '2017-07-10T17:26',
#       'endTimeStr': '5:26 pm',
#       'fareAdult': 550,
#       'fareChild': 300,
#       'fareHopAdult': 0,
#       'fareHopChild': 0,
#       'fareHopTertiary': 0,
#       'from': 'Main Hwy and Amy, 153 Main Hwy',
#       'isFastLeg': False,
#       'isFirst': False,
#       'isLast': False,
#       'legGeometry': {'length': 359,
#        'points': 'dxe`Fg{}i`@KEqDxNETFBECC@UbAMZMFO@oB]yASO@IJG`@@\\lBpI@l@Gf@U~@HDIEgFtSFBGCsCfL_@bB?RBPJROVINkAjA_@Xa@j@wDxFHLIMgI~LgEfGeBnCABFFGGmFdIGJBHCIaHjK}AhBFFGGuHbIDHEIyH~HsAdABJCKgSvOBHCImAbAUXwIvLFHGIiKzNe@v@aEHM@?L?MoJR?R?SiDFg@G}Cs@CPBQsMsCWCg@BQCEVDWaAYsCvTJBKCoDfYcCk@AL?M_GoAQCU?cCl@_AVWJkCp@_Cr@QHWVOd@a@rCFDGEERkAzIK`@sK|SM`@y@c@QOsBkCKJJKo@y@_FmFeGiHcBwAELDMuBoB_HaHuB{BiDwEIJ'},
#       'messages': [],
#       'mode': 'BUS',
#       'provider': 'NZBML',
#       'routeCode': '525',
#       'routeName': 'Sylvia Park to Britomart via Mt Wellington Highway',
#       'startLat': '-36.89875',
#       'startLon': '174.81156',
#       'startTime': '2017-07-10T16:56',
#       'startTimeStr': '4:56 pm',
#       'stops': [{'code': '1501',
#         'geometry': {'data': [-36.89875, 174.81156],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '7505',
#         'geometry': {'data': [-36.89781, 174.80893],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '7503',
#         'geometry': {'data': [-36.89672, 174.8058],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '7501',
#         'geometry': {'data': [-36.89555, 174.8025],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '7615',
#         'geometry': {'data': [-36.89298, 174.79736],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '7613',
#         'geometry': {'data': [-36.88981, 174.79309],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '7611',
#         'geometry': {'data': [-36.88856, 174.79139],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '7609',
#         'geometry': {'data': [-36.88665, 174.78889],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '7607',
#         'geometry': {'data': [-36.8851, 174.78726],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '7605',
#         'geometry': {'data': [-36.8831, 174.7853],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '8480',
#         'geometry': {'data': [-36.87986, 174.78263],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '7601',
#         'geometry': {'data': [-36.87766, 174.77996],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '7207',
#         'geometry': {'data': [-36.87442, 174.77706],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '7205',
#         'geometry': {'data': [-36.87258, 174.77693],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '7203',
#         'geometry': {'data': [-36.87072, 174.7772],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '7201',
#         'geometry': {'data': [-36.86796, 174.77793],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '7177',
#         'geometry': {'data': [-36.86698, 174.77468],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '7231',
#         'geometry': {'data': [-36.86537, 174.77065],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '7227',
#         'geometry': {'data': [-36.86103, 174.76909],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '7149',
#         'geometry': {'data': [-36.85741, 174.76449],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '7147',
#         'geometry': {'data': [-36.85427, 174.76789],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '7145',
#         'geometry': {'data': [-36.85078, 174.77161],
#          'encoded': False,
#          'type': 'point'}}],
#       'to': 'Symonds St and Waterloo, 3 Symonds St',
#       'toStr': 'Bus to Symonds St and Waterloo, 3 Symonds St',
#       'tripId': '6525058379-20170602141618_v54.27'},
#      {'distance': '416 metres',
#       'distanceExact': 416,
#       'distanceStr': '416 metres',
#       'duration': 360000,
#       'durationStr': '6 min',
#       'endLat': '-36.8499741',
#       'endLon': '174.7686468',
#       'endTime': '2017-07-10T17:32',
#       'endTimeStr': '5:32 pm',
#       'fareAdult': 0,
#       'fareChild': 0,
#       'fareHopAdult': 0,
#       'fareHopChild': 0,
#       'fareHopTertiary': 0,
#       'from': 'Symonds St and Waterloo, 3 Symonds St',
#       'isFastLeg': False,
#       'isFirst': False,
#       'isLast': True,
#       'legGeometry': {'length': 23,
#        'points': 'jl|_Fqavi`@BENFlBfC_B|BX^wAxBFN@V_@vAc@OWrAq@S'},
#       'messages': [],
#       'mode': 'WALK',
#       'startLat': '-36.85078',
#       'startLon': '174.77161',
#       'startTime': '2017-07-10T17:26',
#       'startTimeStr': '5:26 pm',
#       'stops': [],
#       'to': 'to',
#       'toStr': 'Walk to to'}],
#     'startTime': '2017-07-10T16:47',
#     'startTimeStr': '4:47 pm'},
#    {'duration': 2760000,
#     'durationStr': 'an hour',
#     'endTime': '2017-07-10T17:42',
#     'endTimeStr': '5:42 pm',
#     'fareAdult': 550,
#     'fareChild': 300,
#     'fareError': None,
#     'fareHopAdult': 315,
#     'fareHopChild': 180,
#     'fareHopTertiary': 235,
#     'fareWarnings': {},
#     'legs': [{'distance': '1088 metres',
#       'distanceExact': 1088,
#       'distanceStr': '1088 metres',
#       'duration': 960000,
#       'durationStr': '16 min',
#       'endLat': '-36.89847',
#       'endLon': '174.80811',
#       'endTime': '2017-07-10T17:12',
#       'endTimeStr': '5:12 pm',
#       'fareAdult': 0,
#       'fareChild': 0,
#       'fareHopAdult': 0,
#       'fareHopChild': 0,
#       'fareHopTertiary': 0,
#       'from': 'from',
#       'isFastLeg': False,
#       'isFirst': True,
#       'isLast': False,
#       'legGeometry': {'length': 51,
#        'points': 'tce`F}q~i`@[lArVtKcHbYITKJBXAFE@CIBGHD\\zAnCgAFP'},
#       'messages': [],
#       'mode': 'WALK',
#       'startLat': '-36.8954602',
#       'startLon': '174.815197',
#       'startTime': '2017-07-10T16:56',
#       'startTimeStr': '4:56 pm',
#       'stops': [],
#       'to': 'Ellerslie Train Station',
#       'toStr': 'Walk to Ellerslie Train Station'},
#      {'distance': 'undefined metres',
#       'distanceStr': 'undefined metres',
#       'duration': 1080000,
#       'durationStr': '18 min',
#       'endLat': '-36.84429',
#       'endLon': '174.76848',
#       'endTime': '2017-07-10T17:30',
#       'endTimeStr': '5:30 pm',
#       'fareAdult': 550,
#       'fareChild': 300,
#       'fareHopAdult': 0,
#       'fareHopChild': 0,
#       'fareHopTertiary': 0,
#       'from': 'Ellerslie Train Station',
#       'isFastLeg': True,
#       'isFirst': False,
#       'isLast': False,
#       'legGeometry': {'length': 715,
#        'points': 'nve`Fue}i`@CIuAl@g@\\kHnCsCxBeBfBaArAuAdByC|EwC`GO^wDnHwEhIuElJBB}AzCcGzLuDzIyAvDeEtH{BtDm@v@]j@uGvHaJjJCAg@d@}H`IoQzO}AlA}@l@kCzAiBx@aBj@sCp@mB\\qBT}CPsALkA?c@CsC]_NaCgEqCqFaFcAiAgAq@u@S_@GsAGu@DcAZmr@r[aKdEsIdCeDl@kAJsAWoAo@y@gBSeAGqAQeB[gAYe@w@i@o@Os@HgAh@k@nAq@rC}Mnt@'},
#       'messages': [],
#       'mode': 'TRAIN',
#       'provider': 'AM',
#       'routeCode': 'STH',
#       'routeName': 'Papakura Train Station to Britomart Train Station',
#       'startLat': '-36.89847',
#       'startLon': '174.80811',
#       'startTime': '2017-07-10T17:12',
#       'startTimeStr': '5:12 pm',
#       'stops': [{'code': '112',
#         'geometry': {'data': [-36.89847, 174.80811],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '113',
#         'geometry': {'data': [-36.88966, 174.79742],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '114',
#         'geometry': {'data': [-36.88138, 174.78542],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '115',
#         'geometry': {'data': [-36.86972, 174.77883],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '140',
#         'geometry': {'data': [-36.85473, 174.7774],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '133',
#         'geometry': {'data': [-36.84429, 174.76848],
#          'encoded': False,
#          'type': 'point'}}],
#       'to': 'Britomart Train Station',
#       'toStr': 'Train to Britomart Train Station',
#       'tripId': '23100071238-20170602141618_v54.27'},
#      {'distance': '800 metres',
#       'distanceExact': 800,
#       'distanceStr': '800 metres',
#       'duration': 720000,
#       'durationStr': '12 min',
#       'endLat': '-36.8499741',
#       'endLon': '174.7686468',
#       'endTime': '2017-07-10T17:42',
#       'endTimeStr': '5:42 pm',
#       'fareAdult': 0,
#       'fareChild': 0,
#       'fareHopAdult': 0,
#       'fareHopChild': 0,
#       'fareHopTertiary': 0,
#       'from': 'Britomart Train Station',
#       'isFastLeg': False,
#       'isFirst': False,
#       'isLast': True,
#       'legGeometry': {'length': 47,
#        'points': 'xc{_F_nui`@JDG`@xBj@VTVRzDjATCF@E\\|@VBLD@JDPk@rBXzAZN@|@UDOfA{@ZQXa@\\OJGPS^Qz@QhAP_@cACQDe@b@N'},
#       'messages': [],
#       'mode': 'WALK',
#       'startLat': '-36.84429',
#       'startLon': '174.76848',
#       'startTime': '2017-07-10T17:30',
#       'startTimeStr': '5:30 pm',
#       'stops': [],
#       'to': 'to',
#       'toStr': 'Walk to to'}],
#     'startTime': '2017-07-10T16:56',
#     'startTimeStr': '4:56 pm'},
#    {'duration': 2520000,
#     'durationStr': '42 minutes',
#     'endTime': '2017-07-10T17:44',
#     'endTimeStr': '5:44 pm',
#     'fareAdult': 550,
#     'fareChild': 300,
#     'fareError': None,
#     'fareHopAdult': 315,
#     'fareHopChild': 180,
#     'fareHopTertiary': 235,
#     'fareWarnings': {},
#     'legs': [{'distance': '1088 metres',
#       'distanceExact': 1088,
#       'distanceStr': '1088 metres',
#       'duration': 960000,
#       'durationStr': '16 min',
#       'endLat': '-36.89847',
#       'endLon': '174.80811',
#       'endTime': '2017-07-10T17:18',
#       'endTimeStr': '5:18 pm',
#       'fareAdult': 0,
#       'fareChild': 0,
#       'fareHopAdult': 0,
#       'fareHopChild': 0,
#       'fareHopTertiary': 0,
#       'from': 'from',
#       'isFastLeg': False,
#       'isFirst': True,
#       'isLast': False,
#       'legGeometry': {'length': 51,
#        'points': 'tce`F}q~i`@[lArVtKcHbYITKJBXAFE@CIBGHD\\zAnCgAFP'},
#       'messages': [],
#       'mode': 'WALK',
#       'startLat': '-36.8954602',
#       'startLon': '174.815197',
#       'startTime': '2017-07-10T17:02',
#       'startTimeStr': '5:02 pm',
#       'stops': [],
#       'to': 'Ellerslie Train Station',
#       'toStr': 'Walk to Ellerslie Train Station'},
#      {'distance': 'undefined metres',
#       'distanceStr': 'undefined metres',
#       'duration': 840000,
#       'durationStr': '14 min',
#       'endLat': '-36.84429',
#       'endLon': '174.76848',
#       'endTime': '2017-07-10T17:32',
#       'endTimeStr': '5:32 pm',
#       'fareAdult': 550,
#       'fareChild': 300,
#       'fareHopAdult': 0,
#       'fareHopChild': 0,
#       'fareHopTertiary': 0,
#       'from': 'Ellerslie Train Station',
#       'isFastLeg': True,
#       'isFirst': False,
#       'isLast': False,
#       'legGeometry': {'length': 1140,
#        'points': 'nve`Fue}i`@cKxDaEtCqFzGaIpN_MnUiKfT}IbSgF|JqFrIgNtOuZtYyGvFgHvDwGfBmEr@{GZyE_@EEsASoGiAo@GW@qAo@wA{@mFmEcCoCw@m@u@]aASWC}@?YBi@JkA`@uQlIsJjEi]~OiBp@_EfAcFbAsARm@?g@Ga@Ko@[[USUWa@Y_AMaAM_CGo@Qy@Q_@g@g@q@Y]EW?a@F[LULc@h@Q^Od@m@zBaHta@[xAU~BYrAgAtGc@V'},
#       'messages': [],
#       'mode': 'TRAIN',
#       'provider': 'AM',
#       'routeCode': 'ONE',
#       'routeName': 'Onehunga Train Station to Britomart Train Station',
#       'startLat': '-36.89847',
#       'startLon': '174.80811',
#       'startTime': '2017-07-10T17:18',
#       'startTimeStr': '5:18 pm',
#       'stops': [{'code': '112',
#         'geometry': {'data': [-36.89847, 174.80811],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '115',
#         'geometry': {'data': [-36.86972, 174.77883],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '133',
#         'geometry': {'data': [-36.84429, 174.76848],
#          'encoded': False,
#          'type': 'point'}}],
#       'to': 'Britomart Train Station',
#       'toStr': 'Train to Britomart Train Station',
#       'tripId': '51100070771-20170602141618_v54.27'},
#      {'distance': '800 metres',
#       'distanceExact': 800,
#       'distanceStr': '800 metres',
#       'duration': 720000,
#       'durationStr': '12 min',
#       'endLat': '-36.8499741',
#       'endLon': '174.7686468',
#       'endTime': '2017-07-10T17:44',
#       'endTimeStr': '5:44 pm',
#       'fareAdult': 0,
#       'fareChild': 0,
#       'fareHopAdult': 0,
#       'fareHopChild': 0,
#       'fareHopTertiary': 0,
#       'from': 'Britomart Train Station',
#       'isFastLeg': False,
#       'isFirst': False,
#       'isLast': True,
#       'legGeometry': {'length': 47,
#        'points': 'xc{_F_nui`@JDG`@xBj@VTVRzDjATCF@E\\|@VBLD@JDPk@rBXzAZN@|@UDOfA{@ZQXa@\\OJGPS^Qz@QhAP_@cACQDe@b@N'},
#       'messages': [],
#       'mode': 'WALK',
#       'startLat': '-36.84429',
#       'startLon': '174.76848',
#       'startTime': '2017-07-10T17:32',
#       'startTimeStr': '5:32 pm',
#       'stops': [],
#       'to': 'to',
#       'toStr': 'Walk to to'}],
#     'startTime': '2017-07-10T17:02',
#     'startTimeStr': '5:02 pm'},
#    {'duration': 2700000,
#     'durationStr': 'an hour',
#     'endTime': '2017-07-10T17:52',
#     'endTimeStr': '5:52 pm',
#     'fareAdult': 550,
#     'fareChild': 300,
#     'fareError': None,
#     'fareHopAdult': 315,
#     'fareHopChild': 180,
#     'fareHopTertiary': 235,
#     'fareWarnings': {},
#     'legs': [{'distance': '1088 metres',
#       'distanceExact': 1088,
#       'distanceStr': '1088 metres',
#       'duration': 960000,
#       'durationStr': '16 min',
#       'endLat': '-36.89847',
#       'endLon': '174.80811',
#       'endTime': '2017-07-10T17:23',
#       'endTimeStr': '5:23 pm',
#       'fareAdult': 0,
#       'fareChild': 0,
#       'fareHopAdult': 0,
#       'fareHopChild': 0,
#       'fareHopTertiary': 0,
#       'from': 'from',
#       'isFastLeg': False,
#       'isFirst': True,
#       'isLast': False,
#       'legGeometry': {'length': 51,
#        'points': 'tce`F}q~i`@[lArVtKcHbYITKJBXAFE@CIBGHD\\zAnCgAFP'},
#       'messages': [],
#       'mode': 'WALK',
#       'startLat': '-36.8954602',
#       'startLon': '174.815197',
#       'startTime': '2017-07-10T17:07',
#       'startTimeStr': '5:07 pm',
#       'stops': [],
#       'to': 'Ellerslie Train Station',
#       'toStr': 'Walk to Ellerslie Train Station'},
#      {'distance': 'undefined metres',
#       'distanceStr': 'undefined metres',
#       'duration': 1020000,
#       'durationStr': '17 min',
#       'endLat': '-36.84429',
#       'endLon': '174.76848',
#       'endTime': '2017-07-10T17:40',
#       'endTimeStr': '5:40 pm',
#       'fareAdult': 550,
#       'fareChild': 300,
#       'fareHopAdult': 0,
#       'fareHopChild': 0,
#       'fareHopTertiary': 0,
#       'from': 'Ellerslie Train Station',
#       'isFastLeg': True,
#       'isFirst': False,
#       'isLast': False,
#       'legGeometry': {'length': 715,
#        'points': 'nve`Fue}i`@CIuAl@g@\\kHnCsCxBeBfBaArAuAdByC|EwC`GO^wDnHwEhIuElJBB}AzCcGzLuDzIyAvDeEtH{BtDm@v@]j@uGvHaJjJCAg@d@}H`IoQzO}AlA}@l@kCzAiBx@aBj@sCp@mB\\qBT}CPsALkA?c@CsC]_NaCgEqCqFaFcAiAgAq@u@S_@GsAGu@DcAZmr@r[aKdEsIdCeDl@kAJsAWoAo@y@gBSeAGqAQeB[gAYe@w@i@o@Os@HgAh@k@nAq@rC}Mnt@'},
#       'messages': [],
#       'mode': 'TRAIN',
#       'provider': 'AM',
#       'routeCode': 'STH',
#       'routeName': 'Papakura Train Station to Britomart Train Station',
#       'startLat': '-36.89847',
#       'startLon': '174.80811',
#       'startTime': '2017-07-10T17:23',
#       'startTimeStr': '5:23 pm',
#       'stops': [{'code': '112',
#         'geometry': {'data': [-36.89847, 174.80811],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '113',
#         'geometry': {'data': [-36.88966, 174.79742],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '114',
#         'geometry': {'data': [-36.88138, 174.78542],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '115',
#         'geometry': {'data': [-36.86972, 174.77883],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '140',
#         'geometry': {'data': [-36.85473, 174.7774],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '133',
#         'geometry': {'data': [-36.84429, 174.76848],
#          'encoded': False,
#          'type': 'point'}}],
#       'to': 'Britomart Train Station',
#       'toStr': 'Train to Britomart Train Station',
#       'tripId': '23100071239-20170602141618_v54.27'},
#      {'distance': '800 metres',
#       'distanceExact': 800,
#       'distanceStr': '800 metres',
#       'duration': 720000,
#       'durationStr': '12 min',
#       'endLat': '-36.8499741',
#       'endLon': '174.7686468',
#       'endTime': '2017-07-10T17:52',
#       'endTimeStr': '5:52 pm',
#       'fareAdult': 0,
#       'fareChild': 0,
#       'fareHopAdult': 0,
#       'fareHopChild': 0,
#       'fareHopTertiary': 0,
#       'from': 'Britomart Train Station',
#       'isFastLeg': False,
#       'isFirst': False,
#       'isLast': True,
#       'legGeometry': {'length': 47,
#        'points': 'xc{_F_nui`@JDG`@xBj@VTVRzDjATCF@E\\|@VBLD@JDPk@rBXzAZN@|@UDOfA{@ZQXa@\\OJGPS^Qz@QhAP_@cACQDe@b@N'},
#       'messages': [],
#       'mode': 'WALK',
#       'startLat': '-36.84429',
#       'startLon': '174.76848',
#       'startTime': '2017-07-10T17:40',
#       'startTimeStr': '5:40 pm',
#       'stops': [],
#       'to': 'to',
#       'toStr': 'Walk to to'}],
#     'startTime': '2017-07-10T17:07',
#     'startTimeStr': '5:07 pm'},
#    {'duration': 2940000,
#     'durationStr': 'an hour',
#     'endTime': '2017-07-10T17:57',
#     'endTimeStr': '5:57 pm',
#     'fareAdult': 550,
#     'fareChild': 300,
#     'fareError': None,
#     'fareHopAdult': 315,
#     'fareHopChild': 180,
#     'fareHopTertiary': 235,
#     'fareWarnings': {},
#     'legs': [{'distance': '135 metres',
#       'distanceExact': 135,
#       'distanceStr': '135 metres',
#       'duration': 120000,
#       'durationStr': '1 min',
#       'endLat': '-36.89611',
#       'endLon': '174.81445',
#       'endTime': '2017-07-10T17:10',
#       'endTimeStr': '5:10 pm',
#       'fareAdult': 0,
#       'fareChild': 0,
#       'fareHopAdult': 0,
#       'fareHopChild': 0,
#       'fareHopTertiary': 0,
#       'from': 'from',
#       'isFastLeg': False,
#       'isFirst': True,
#       'isLast': False,
#       'legGeometry': {'length': 5, 'points': 'tce`F}q~i`@[lAvCpABK'},
#       'messages': [],
#       'mode': 'WALK',
#       'startLat': '-36.8954602',
#       'startLon': '174.815197',
#       'startTime': '2017-07-10T17:08',
#       'startTimeStr': '5:08 pm',
#       'stops': [],
#       'to': 'Amy St and Ballin, 32 Amy St',
#       'toStr': 'Walk to Amy St and Ballin, 32 Amy St'},
#      {'distance': 'undefined metres',
#       'distanceStr': 'undefined metres',
#       'duration': 2460000,
#       'durationStr': '41 min',
#       'endLat': '-36.85078',
#       'endLon': '174.77161',
#       'endTime': '2017-07-10T17:51',
#       'endTimeStr': '5:51 pm',
#       'fareAdult': 550,
#       'fareChild': 300,
#       'fareHopAdult': 0,
#       'fareHopChild': 0,
#       'fareHopTertiary': 0,
#       'from': 'Amy St and Ballin, 32 Amy St',
#       'isFastLeg': False,
#       'isFirst': False,
#       'isLast': False,
#       'legGeometry': {'length': 368,
#        'points': 'tge`Fim~i`@CHnB~@vJjEpBv@qAlFJDKEqDxNETFBECC@UbAMZMFO@oB]yASO@IJG`@@\\fBzHFd@?\\Gf@U~@HDIEgFtSFBGCoD`OC\\BPJRYf@uArAUPa@j@wDxFHLIMgI~LgEfGeBnCABFFGGmFdIGJBHCIaHjK}AhBFFGGuHbIDHEIyH~HsAdABJCKgSvOBHCImAbAUXwIvLFHGIiKzNe@v@aEHM@?L?MoJR?R?SiDFg@G}Cs@CPBQsMsCWCg@BQCEVDWaAYsCvTJBKCoDfYcCk@AL?M_GoAQCU?cCl@_AVWJkCp@_Cr@QHWVOd@a@rCFDGEERkAzIK`@sK|SM`@y@c@QOsBkCKJJKo@y@_FmFeGiHcBwAELDMuBoB_HaHuB{BiDwEIJ'},
#       'messages': [],
#       'mode': 'BUS',
#       'provider': 'NZBML',
#       'routeCode': '595',
#       'routeName': 'Glen Innes Centre To Britomart Via Panmure And Ellerslie',
#       'startLat': '-36.89611',
#       'startLon': '174.81445',
#       'startTime': '2017-07-10T17:10',
#       'startTimeStr': '5:10 pm',
#       'stops': [{'code': '7463',
# ...
#         'geometry': {'data': [-36.8851, 174.78726],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '7605',
#         'geometry': {'data': [-36.8831, 174.7853],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '8480',
#         'geometry': {'data': [-36.87986, 174.78263],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '7601',
#         'geometry': {'data': [-36.87766, 174.77996],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '7207',
#         'geometry': {'data': [-36.87442, 174.77706],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '7205',
#         'geometry': {'data': [-36.87258, 174.77693],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '7203',
#         'geometry': {'data': [-36.87072, 174.7772],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '7201',
#         'geometry': {'data': [-36.86796, 174.77793],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '7177',
#         'geometry': {'data': [-36.86698, 174.77468],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '7231',
#         'geometry': {'data': [-36.86537, 174.77065],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '7227',
#         'geometry': {'data': [-36.86103, 174.76909],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '7149',
#         'geometry': {'data': [-36.85741, 174.76449],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '7147',
#         'geometry': {'data': [-36.85427, 174.76789],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '7145',
#         'geometry': {'data': [-36.85078, 174.77161],
#          'encoded': False,
#          'type': 'point'}}],
#       'to': 'Symonds St and Waterloo, 3 Symonds St',
#       'toStr': 'Bus to Symonds St and Waterloo, 3 Symonds St',
#       'tripId': '14595039914-20170602141618_v54.27'},
#      {'distance': '416 metres',
#       'distanceExact': 416,
#       'distanceStr': '416 metres',
#       'duration': 360000,
#       'durationStr': '6 min',
#       'endLat': '-36.8499741',
#       'endLon': '174.7686468',
#       'endTime': '2017-07-10T17:57',
#       'endTimeStr': '5:57 pm',
#       'fareAdult': 0,
#       'fareChild': 0,
#       'fareHopAdult': 0,
#       'fareHopChild': 0,
#       'fareHopTertiary': 0,
#       'from': 'Symonds St and Waterloo, 3 Symonds St',
#       'isFastLeg': False,
#       'isFirst': False,
#       'isLast': True,
#       'legGeometry': {'length': 23,
#        'points': 'jl|_Fqavi`@BENFlBfC_B|BX^wAxBFN@V_@vAc@OWrAq@S'},
#       'messages': [],
#       'mode': 'WALK',
#       'startLat': '-36.85078',
#       'startLon': '174.77161',
#       'startTime': '2017-07-10T17:51',
#       'startTimeStr': '5:51 pm',
#       'stops': [],
#       'to': 'to',
#       'toStr': 'Walk to to'}],
#     'startTime': '2017-07-10T17:08',
#     'startTimeStr': '5:08 pm'},
#    {'duration': 2640000,
#     'durationStr': '44 minutes',
#     'endTime': '2017-07-10T17:52',
#     'endTimeStr': '5:52 pm',
#     'fareAdult': 900,
#     'fareChild': 500,
#     'fareError': None,
#     'fareHopAdult': 315,
#     'fareHopChild': 180,
#     'fareHopTertiary': 235,
#     'fareWarnings': {},
#     'legs': [{'distance': '135 metres',
#       'distanceExact': 135,
#       'distanceStr': '135 metres',
#       'duration': 120000,
#       'durationStr': '1 min',
#       'endLat': '-36.89611',
#       'endLon': '174.81445',
#       'endTime': '2017-07-10T17:10',
#       'endTimeStr': '5:10 pm',
#       'fareAdult': 0,
#       'fareChild': 0,
#       'fareHopAdult': 0,
#       'fareHopChild': 0,
#       'fareHopTertiary': 0,
#       'from': 'from',
#       'isFastLeg': False,
#       'isFirst': True,
#       'isLast': False,
#       'legGeometry': {'length': 5, 'points': 'tce`F}q~i`@[lAvCpABK'},
#       'messages': [],
#       'mode': 'WALK',
#       'startLat': '-36.8954602',
#       'startLon': '174.815197',
#       'startTime': '2017-07-10T17:08',
#       'startTimeStr': '5:08 pm',
#       'stops': [],
#       'to': 'Amy St and Ballin, 32 Amy St',
#       'toStr': 'Walk to Amy St and Ballin, 32 Amy St'},
#      {'distance': 'undefined metres',
#       'distanceStr': 'undefined metres',
#       'duration': 120000,
#       'durationStr': '1 min',
#       'endLat': '-36.89781',
#       'endLon': '174.80893',
#       'endTime': '2017-07-10T17:12',
#       'endTimeStr': '5:12 pm',
#       'fareAdult': 350,
#       'fareChild': 200,
#       'fareHopAdult': 0,
#       'fareHopChild': 0,
#       'fareHopTertiary': 0,
#       'from': 'Amy St and Ballin, 32 Amy St',
#       'isFastLeg': False,
#       'isFirst': False,
#       'isLast': False,
#       'legGeometry': {'length': 15,
#        'points': 'tge`Fim~i`@CHnB~@vJjEpBv@qAlFJDKEqDxNETFB'},
#       'messages': [],
#       'mode': 'BUS',
#       'provider': 'NZBML',
#       'routeCode': '595',
#       'routeName': 'Glen Innes Centre To Britomart Via Panmure And Ellerslie',
#       'startLat': '-36.89611',
#       'startLon': '174.81445',
#       'startTime': '2017-07-10T17:10',
#       'startTimeStr': '5:10 pm',
#       'stops': [{'code': '7463',
#         'geometry': {'data': [-36.89611, 174.81445],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '1501',
#         'geometry': {'data': [-36.89875, 174.81156],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '7505',
#         'geometry': {'data': [-36.89781, 174.80893],
#          'encoded': False,
#          'type': 'point'}}],
#       'to': 'Ellerslie, 95 Main Hwy',
#       'toStr': 'Bus to Ellerslie, 95 Main Hwy',
#       'tripId': '14595039914-20170602141618_v54.27'},
#      {'distance': '232 metres',
#       'distanceExact': 232,
#       'distanceStr': '232 metres',
#       'duration': 180000,
#       'durationStr': '3 min',
#       'endLat': '-36.89847',
#       'endLon': '174.80811',
#       'endTime': '2017-07-10T17:15',
#       'endTimeStr': '5:15 pm',
#       'fareAdult': 0,
#       'fareChild': 0,
#       'fareHopAdult': 0,
#       'fareHopChild': 0,
#       'fareHopTertiary': 0,
#       'from': 'Ellerslie, 95 Main Hwy',
#       'isFastLeg': False,
#       'isFirst': False,
#       'isLast': False,
#       'legGeometry': {'length': 33,
#        'points': 'hre`Fyj}i`@GCWfAITKJBXAFE@CIBGHD\\zAnCgAFP'},
#       'messages': [],
#       'mode': 'WALK',
#       'startLat': '-36.89781',
#       'startLon': '174.80893',
#       'startTime': '2017-07-10T17:12',
#       'startTimeStr': '5:12 pm',
#       'stops': [],
#       'to': 'Ellerslie Train Station',
#       'toStr': 'Walk to Ellerslie Train Station'},
#      {'distance': 'undefined metres',
#       'distanceStr': 'undefined metres',
#       'duration': 1020000,
#       'durationStr': '17 min',
#       'endLat': '-36.84429',
#       'endLon': '174.76848',
#       'endTime': '2017-07-10T17:40',
#       'endTimeStr': '5:40 pm',
#       'fareAdult': 550,
#       'fareChild': 300,
#       'fareHopAdult': 0,
#       'fareHopChild': 0,
#       'fareHopTertiary': 0,
#       'from': 'Ellerslie Train Station',
#       'isFastLeg': True,
#       'isFirst': False,
#       'isLast': False,
#       'legGeometry': {'length': 715,
#        'points': 'nve`Fue}i`@CIuAl@g@\\kHnCsCxBeBfBaArAuAdByC|EwC`GO^wDnHwEhIuElJBB}AzCcGzLuDzIyAvDeEtH{BtDm@v@]j@uGvHaJjJCAg@d@}H`IoQzO}AlA}@l@kCzAiBx@aBj@sCp@mB\\qBT}CPsALkA?c@CsC]_NaCgEqCqFaFcAiAgAq@u@S_@GsAGu@DcAZmr@r[aKdEsIdCeDl@kAJsAWoAo@y@gBSeAGqAQeB[gAYe@w@i@o@Os@HgAh@k@nAq@rC}Mnt@'},
#       'messages': [],
#       'mode': 'TRAIN',
#       'provider': 'AM',
#       'routeCode': 'STH',
#       'routeName': 'Papakura Train Station to Britomart Train Station',
#       'startLat': '-36.89847',
#       'startLon': '174.80811',
#       'startTime': '2017-07-10T17:23',
#       'startTimeStr': '5:23 pm',
#       'stops': [{'code': '112',
#         'geometry': {'data': [-36.89847, 174.80811],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '113',
#         'geometry': {'data': [-36.88966, 174.79742],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '114',
#         'geometry': {'data': [-36.88138, 174.78542],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '115',
#         'geometry': {'data': [-36.86972, 174.77883],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '140',
#         'geometry': {'data': [-36.85473, 174.7774],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '133',
#         'geometry': {'data': [-36.84429, 174.76848],
#          'encoded': False,
#          'type': 'point'}}],
#       'to': 'Britomart Train Station',
#       'toStr': 'Train to Britomart Train Station',
#       'tripId': '23100071239-20170602141618_v54.27'},
#      {'distance': '800 metres',
#       'distanceExact': 800,
#       'distanceStr': '800 metres',
#       'duration': 720000,
#       'durationStr': '12 min',
#       'endLat': '-36.8499741',
#       'endLon': '174.7686468',
#       'endTime': '2017-07-10T17:52',
#       'endTimeStr': '5:52 pm',
#       'fareAdult': 0,
#       'fareChild': 0,
#       'fareHopAdult': 0,
#       'fareHopChild': 0,
#       'fareHopTertiary': 0,
#       'from': 'Britomart Train Station',
#       'isFastLeg': False,
#       'isFirst': False,
#       'isLast': True,
#       'legGeometry': {'length': 47,
#        'points': 'xc{_F_nui`@JDG`@xBj@VTVRzDjATCF@E\\|@VBLD@JDPk@rBXzAZN@|@UDOfA{@ZQXa@\\OJGPS^Qz@QhAP_@cACQDe@b@N'},
#       'messages': [],
#       'mode': 'WALK',
#       'startLat': '-36.84429',
#       'startLon': '174.76848',
#       'startTime': '2017-07-10T17:40',
#       'startTimeStr': '5:40 pm',
#       'stops': [],
#       'to': 'to',
#       'toStr': 'Walk to to'}],
#     'startTime': '2017-07-10T17:08',
#     'startTimeStr': '5:08 pm'},
#    {'duration': 2880000,
#     'durationStr': 'an hour',
#     'endTime': '2017-07-10T18:00',
#     'endTimeStr': '6:00 pm',
#     'fareAdult': 550,
#     'fareChild': 300,
#     'fareError': None,
#     'fareHopAdult': 315,
#     'fareHopChild': 180,
#     'fareHopTertiary': 235,
#     'fareWarnings': {},
#     'legs': [{'distance': '614 metres',
#       'distanceExact': 614,
#       'distanceStr': '614 metres',
#       'duration': 540000,
#       'durationStr': '9 min',
#       'endLat': '-36.89875',
#       'endLon': '174.81156',
#       'endTime': '2017-07-10T17:21',
#       'endTimeStr': '5:21 pm',
#       'fareAdult': 0,
#       'fareChild': 0,
#       'fareHopAdult': 0,
#       'fareHopChild': 0,
#       'fareHopTertiary': 0,
#       'from': 'from',
#       'isFastLeg': False,
#       'isFirst': True,
#       'isLast': False,
#       'legGeometry': {'length': 15, 'points': 'tce`F}q~i`@[lArVtKsAjFJD'},
#       'messages': [],
#       'mode': 'WALK',
#       'startLat': '-36.8954602',
#       'startLon': '174.815197',
#       'startTime': '2017-07-10T17:12',
#       'startTimeStr': '5:12 pm',
#       'stops': [],
#       'to': 'Main Hwy and Amy, 153 Main Hwy',
#       'toStr': 'Walk to Main Hwy and Amy, 153 Main Hwy'},
#      {'distance': 'undefined metres',
#       'distanceStr': 'undefined metres',
#       'duration': 1980000,
#       'durationStr': '33 min',
#       'endLat': '-36.85078',
#       'endLon': '174.77161',
#       'endTime': '2017-07-10T17:54',
#       'endTimeStr': '5:54 pm',
#       'fareAdult': 550,
#       'fareChild': 300,
#       'fareHopAdult': 0,
#       'fareHopChild': 0,
#       'fareHopTertiary': 0,
#       'from': 'Main Hwy and Amy, 153 Main Hwy',
#       'isFastLeg': False,
#       'isFirst': False,
#       'isLast': False,
#       'legGeometry': {'length': 359,
#        'points': 'dxe`Fg{}i`@KEqDxNETFBECC@UbAMZMFO@oB]yASO@IJG`@@\\lBpI@l@Gf@U~@HDIEgFtSFBGCsCfL_@bB?RBPJROVINkAjA_@Xa@j@wDxFHLIMgI~LgEfGeBnCABFFGGmFdIGJBHCIaHjK}AhBFFGGuHbIDHEIyH~HsAdABJCKgSvOBHCImAbAUXwIvLFHGIiKzNe@v@aEHM@?L?MoJR?R?SiDFg@G}Cs@CPBQsMsCWCg@BQCEVDWaAYsCvTJBKCoDfYcCk@AL?M_GoAQCU?cCl@_AVWJkCp@_Cr@QHWVOd@a@rCFDGEERkAzIK`@sK|SM`@y@c@QOsBkCKJJKo@y@_FmFeGiHcBwAELDMuBoB_HaHuB{BiDwEIJ'},
#       'messages': [],
#       'mode': 'BUS',
#       'provider': 'NZBML',
#       'routeCode': '532',
#       'routeName': 'Otahuhu Station to Britomart via Carbine Road',
#       'startLat': '-36.89875',
#       'startLon': '174.81156',
#       'startTime': '2017-07-10T17:21',
#       'startTimeStr': '5:21 pm',
#       'stops': [{'code': '1501',
#         'geometry': {'data': [-36.89875, 174.81156],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '7505',
#         'geometry': {'data': [-36.89781, 174.80893],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '7503',
#         'geometry': {'data': [-36.89672, 174.8058],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '7501',
#         'geometry': {'data': [-36.89555, 174.8025],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '7615',
#         'geometry': {'data': [-36.89298, 174.79736],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '7613',
#         'geometry': {'data': [-36.88981, 174.79309],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '7611',
#         'geometry': {'data': [-36.88856, 174.79139],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '7609',
#         'geometry': {'data': [-36.88665, 174.78889],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '7607',
#         'geometry': {'data': [-36.8851, 174.78726],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '7605',
#         'geometry': {'data': [-36.8831, 174.7853],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '8480',
#         'geometry': {'data': [-36.87986, 174.78263],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '7601',
#         'geometry': {'data': [-36.87766, 174.77996],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '7207',
#         'geometry': {'data': [-36.87442, 174.77706],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '7205',
#         'geometry': {'data': [-36.87258, 174.77693],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '7203',
#         'geometry': {'data': [-36.87072, 174.7772],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '7201',
#         'geometry': {'data': [-36.86796, 174.77793],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '7177',
#         'geometry': {'data': [-36.86698, 174.77468],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '7231',
#         'geometry': {'data': [-36.86537, 174.77065],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '7227',
#         'geometry': {'data': [-36.86103, 174.76909],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '7149',
#         'geometry': {'data': [-36.85741, 174.76449],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '7147',
#         'geometry': {'data': [-36.85427, 174.76789],
#          'encoded': False,
#          'type': 'point'}},
#        {'code': '7145',
#         'geometry': {'data': [-36.85078, 174.77161],
#          'encoded': False,
#          'type': 'point'}}],
#       'to': 'Symonds St and Waterloo, 3 Symonds St',
#       'toStr': 'Bus to Symonds St and Waterloo, 3 Symonds St',
#       'tripId': '15532054174-20170602141618_v54.27'},
#      {'distance': '416 metres',
#       'distanceExact': 416,
#       'distanceStr': '416 metres',
#       'duration': 360000,
#       'durationStr': '6 min',
#       'endLat': '-36.8499741',
#       'endLon': '174.7686468',
#       'endTime': '2017-07-10T18:00',
#       'endTimeStr': '6:00 pm',
#       'fareAdult': 0,
#       'fareChild': 0,
#       'fareHopAdult': 0,
#       'fareHopChild': 0,
#       'fareHopTertiary': 0,
#       'from': 'Symonds St and Waterloo, 3 Symonds St',
#       'isFastLeg': False,
#       'isFirst': False,
#       'isLast': True,
#       'legGeometry': {'length': 23,
#        'points': 'jl|_Fqavi`@BENFlBfC_B|BX^wAxBFN@V_@vAc@OWrAq@S'},
#       'messages': [],
#       'mode': 'WALK',
#       'startLat': '-36.85078',
#       'startLon': '174.77161',
#       'startTime': '2017-07-10T17:54',
#       'startTimeStr': '5:54 pm',
#       'stops': [],
#       'to': 'to',
#       'toStr': 'Walk to to'}],
#     'startTime': '2017-07-10T17:12',
#     'startTimeStr': '5:12 pm'}]},
#  'status': 'OK'}

# %%
regions = ['auckland', 'wellington']
for region in regions:
    rp = get_data(region, 'rental_points')
    departure_time = '2017-06-01T07:30:00'
    g = collect_fares(rp, departure_time, region)

    path = get_path(region, 'transit_costs')
    g.to_csv(str(path), index=False)
    print('* ', region)
    print(g.head())

# %%
# # Fill some holes

# def get_transit_costs_with_coords(region):
#     f = hp.get_data(region, 'transit_costs')
#     g = hp.get_data(region, 'rental_points')
#     g['coords'] = g['geometry'].map(lambda g: g.coords[0])
#     f = f.merge(g[['rental_area', 'coords']].rename(columns={
#         'rental_area': 'orig_name',
#         'coords': 'orig_coords',
#     }))
#     f = f.merge(g[['rental_area', 'coords']].rename(columns={
#         'rental_area': 'dest_name',
#         'coords': 'dest_coords',
#     }))
#     return f.sort_values(['orig_name', 'dest_name'])

# def fill_holes(region, departure_time=None):
#     f = get_transit_costs_with_coords(region)
#     cond = f['card_fare'].isnull()
    
#     if region == 'auckland':
#         get_journey = get_journey_auckland
#         get_fare = get_fare_auckland
#         time_per_call = 3.6
#     elif region == 'wellington':
#         get_journey = get_journey_wellington
#         get_fare = get_fare_wellington
#         time_per_call = 2.4
    
#     print('This will take about {:02f} minutes'.format(f[cond].shape[0]*time_per_call/60))
        
#     new_rows = []
#     for __, row in f[cond].iterrows():
#         try:
#             journey = get_journey(row['orig_coords'], row['dest_coords'], departure_time=departure_time)
#             fare = get_fare(journey)
#         except:
#             fare = np.nan
#         new_rows.append([row['orig_name'], row['dest_name'], fare])
#     g = pd.DataFrame(new_rows, columns=['orig_name', 'dest_name', 'card_fare']).fillna(value=np.nan)

#     f = f[~cond].drop(['orig_coords', 'dest_coords'], axis=1)
#     f = pd.concat([f, g]).sort_values(['orig_name', 'dest_name'])
#     return f

# %%
# departure_time = '2017-06-01T07:30:00'
# for region in ['wellington']:
#     f = fill_holes(region, departure_time=departure_time)
#     path = hp.get_path(region, 'transit_costs')
#     path = path.parent/(path.name + '.new')
#     f.to_csv(str(path), index=False)
# Out:
# This will take about 10.040000 minutes

# %% [markdown]
# # Canterbury has no fare calculator API. So estimate Canterbury fares from fare zones and fare table.

# %%
# Fares
fares = pd.DataFrame([[1, 2.55], [2, 3.75]], columns=['#zones_traveled', 'card_fare'])
fares

# Zones
path = DATA_DIR/'canterbury'/'fare_zones.geojson'
zones = gpd.read_file(str(path))
zones

# Attach zones to rental points
rp = hp.get_data('canterbury', 'rental_points')
g = gpd.sjoin(rp, zones, op='within')
g = g[['rental_area', 'zone']].copy()
g.head()

# Compute origin and destination zones
f = hp.get_data('canterbury', 'commutes_transit')
f = f.merge(g.rename(columns={'rental_area': 'orig_name', 'zone': 'orig_zone'}))
f = f.merge(g.rename(columns={'rental_area': 'dest_name', 'zone': 'dest_zone'}))

# Compute #zones traveled, then card fare
f['#zones_traveled'] = abs(f['orig_zone'] - f['dest_zone']) + 1
f = f.merge(fares)

# Cut down and save
f = f[['orig_name', 'dest_name', 'card_fare']].copy()
path = hp.get_path('canterbury', 'transit_costs')
f.to_csv(str(path), index=False)
f
